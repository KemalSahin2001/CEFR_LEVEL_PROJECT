# %%
from PyPDF2 import PdfReader

def extract_text_from_pdf(pdf_path):
    pdf = PdfReader(pdf_path)
    text = ''
    for page in pdf.pages:
        text += page.extract_text()
    return text

# %%
import re

def process_pdf_text(text, existing_cefr_levels):
    lines = text.split('\n')
    start_index = next((i for i, line in enumerate(lines) if re.match(r'^[A-C][1-2]$', line)), 0)
    for line in lines[start_index:]:
        if re.match(r'^[A-C][1-2]$', line):
            current_level = line
        elif line:
            parts = line.split(' ', 1)
            if len(parts) == 2:
                word, pos = parts
                if word and pos and word.lower() not in existing_cefr_levels:
                    existing_cefr_levels[word.lower()] = (current_level, pos)

    # Convert dictionary to list, delete first 6 items, and convert back to dictionary
    existing_cefr_levels = dict(list(existing_cefr_levels.items())[6:])

    return existing_cefr_levels

# %%
pdf_paths = ['American_Oxford_3000_by_CEFR_level.pdf', 'American_Oxford_5000_by_CEFR_level.pdf', 'The_Oxford_3000_by_CEFR_level.pdf', 'The_Oxford_5000_by_CEFR_level.pdf']  # Replace with your actual PDF paths
cefr_levels = {}
for pdf_path in pdf_paths:
    pdf_text = extract_text_from_pdf(pdf_path)
    new_cefr_levels = process_pdf_text(pdf_text,{'A1':1, 'A2':2, 'B1':3, 'B2':4, 'C1':5, 'C2':6})
    cefr_levels.update(new_cefr_levels)  # Merge the new levels into the existing dictionary

# %%
for key, value in cefr_levels.items():
    print(f"{key}: {value}")
# Out:
# a,: ('A1', 'an indefinite article')
# about: ('A1', 'prep. , adv.')
# above: ('A1', 'prep. , adv.')
# across: ('A1', 'prep. , adv.')
# action: ('A1', 'n.')
# activity: ('A1', 'n.')
# actor: ('A1', 'n.')
# actress: ('A1', 'n.')
# add: ('A1', 'v.')
# address: ('A1', 'n.')
# adult: ('A1', 'n.')
# advice: ('A1', 'n.')
# afraid: ('A1', 'adj.')
# after: ('A1', 'prep.')
# afternoon: ('A1', 'n.')
# again: ('A1', 'adv.')
# age: ('A1', 'n.')
# ago: ('A1', 'adv.')
# agree: ('A1', 'v.')
# air: ('A1', 'n.')
# airport: ('A1', 'n.')
# all: ('A1', 'det. , pron.')
# also: ('A1', 'adv.')
# always: ('A1', 'adv.')
# amazing: ('A1', 'adj.')
# and: ('A1', 'conj.')
# angry: ('A1', 'adj.')
# animal: ('A1', 'n.')
# another: ('A1', 'det./pron.')
# answer: ('A1', 'n. , v.')
# any: ('A1', 'det. , pron.')
# anyone: ('A1', 'pron.')
# anything: ('A1', 'pron.')
# apartment: ('A1', 'n.')
# apple: ('A1', 'n.')
# april: ('A1', 'n.')
# area: ('A1', 'n.')
# arm: ('C1', 'v.')
# around: ('A1', 'prep. , adv.')
# arrive: ('A1', 'v.')
# art: ('A1', 'n.')
# article: ('A1', 'n.')
# artist: ('A1', 'n.')
# as: ('A1', 'prep.')
# ask: ('A1', 'v.')
# at: ('A1', 'prep.')
# august: ('A1', 'n.')
# aunt: ('A1', 'n.')
# away: ('A1', 'adv.')
# awesome: ('A1', 'adj. ')
# baby: ('A1', 'n.')
# back: ('A1', 'n. , adv.')
# bad: ('A1', 'adj.')
# bag: ('A1', 'n.')
# ball: ('A1', 'n.')
# banana: ('A1', 'n.')
# bank: ('A1', '(money) n.')
# bar: ('A2', 'n.')
# baseball: ('A2', 'n.')
# basketball: ('A2', 'n.')
# bath: ('A1', 'n.bathroom n.')
# bathroom: ('A1', 'n.')
# be: ('A1', 'v. , auxiliary v.')
# beach: ('A1', 'n.')
# beautiful: ('A1', 'adj.')
# because: ('A1', 'conj.')
# become: ('A1', 'v.')
# bed: ('A1', 'n.')
# bedroom: ('A1', 'n.')
# beer: ('A1', 'n.')
# before: ('A1', 'prep.')
# begin: ('A1', 'v.')
# beginning: ('A1', 'n.')
# behind: ('A1', 'prep. , adv.')
# believe: ('A1', 'v.')
# below: ('A1', 'adv. , prep.')
# best: ('A1', 'adj.')
# better: ('A1', 'adj.')
# between: ('A1', 'prep.')
# bicycle: ('A1', 'n.')
# big: ('A1', 'adj.')
# bike: ('A1', 'n.')
# bill: ('A1', 'n.')
# bird: ('A1', 'n.')
# birthday: ('A1', 'n.')
# black: ('A1', 'adj. , n.')
# blog: ('A1', 'n.')
# blond: ('A1', 'adj.')
# blue: ('A1', 'adj. , n.')
# boat: ('A1', 'n.')
# body: ('A1', 'n.')
# book: ('A1', 'n.')
# boot: ('A1', 'n.')
# bored: ('A1', 'adj.')
# boring: ('A1', 'adj.')
# born: ('A1', 'v.')
# both: ('A1', 'det./pron.')
# bottle: ('A1', 'n.')
# box: ('A1', 'n.')
# boy: ('A1', 'n.')
# boyfriend: ('A1', 'n.')
# bread: ('A1', 'n.')
# break: ('A1', 'v. , n.')
# breakfast: ('A1', 'n.')
# bring: ('A1', 'v.')
# brother: ('A1', 'n.')
# brown: ('A1', 'adj. , n.')
# build: ('A1', 'v.')
# building: ('A1', 'n.')
# bus: ('A1', 'n.')
# business: ('A1', 'n.')
# busy: ('A1', 'adj.')
# but: ('A1', 'conj.')
# buy: ('A1', 'v.')
# by: ('A1', 'prep.')
# bye: ('A1', 'exclam.')
# cafe: ('A1', 'n.')
# cake: ('A1', 'n.')
# call: ('A1', 'v. , n.')
# camera: ('A1', 'n.')
# can1: ('A1', 'modal v.cannot modal v.')
# cannot: ('A1', 'modal v.')
# capital: ('A1', 'n. , adj.')
# car: ('A1', 'n.')
# card: ('A1', 'n.')
# career: ('A1', 'n.')
# carrot: ('A1', 'n.')
# carry: ('A1', 'v.')
# cat: ('A1', 'n.')
# cd: ('A1', 'n.')
# cent: ('A1', 'n.')
# center: ('A1', 'n.')
# chair: ('A1', 'n.')
# change: ('A1', 'v. , n.')
# chart: ('A1', 'n.')
# cheap: ('A1', 'adj.')
# check: ('A1', 'v.')
# cheese: ('A1', 'n.')
# chicken: ('A1', 'n.')
# child: ('A1', 'n.')
# chocolate: ('A1', 'n.')
# choose: ('A1', 'v.')
# city: ('A1', 'n.')
# class: ('A1', 'n.')
# classroom: ('A1', 'n.')
# clean: ('A1', 'adj. , v.')
# climb: ('A1', 'v.')
# clock: ('A1', 'n.')
# close1: ('A1', 'v.')
# clothes: ('A1', 'n.')
# club: ('A1', 'n.')
# coat: ('A1', 'n.')
# coffee: ('A1', 'n.')
# cold: ('A1', 'adj. , n.')
# college: ('A1', 'n.')
# color: ('A1', 'n.')
# come: ('A1', 'v.')
# common: ('A1', 'adj.')
# company: ('A1', 'n.')
# compare: ('A1', 'v.')
# complete: ('A1', 'adj. , v.')
# computer: ('A1', 'n.')
# concert: ('A1', 'n.')
# conversation: ('A1', 'n.')
# cook: ('A1', 'v.')
# cooking: ('A1', 'n.')
# cool: ('A1', 'adj.')
# correct: ('A1', 'adj. , v.')
# cost: ('A1', 'n. , v.')
# could: ('A1', 'modal v.')
# course: ('A1', 'n.')
# cousin: ('A1', 'n.')
# cow: ('A1', 'n.')
# cream: ('A1', 'n.')
# create: ('A1', 'v.')
# culture: ('A1', 'n.')
# cup: ('A1', 'n.')
# customer: ('A1', 'n.')
# cut: ('A1', 'v.dad n.')
# dad: ('A1', 'n.')
# dance: ('A1', 'n. , v.')
# dancer: ('A1', 'n.')
# dancing: ('A1', 'n.')
# dangerous: ('A1', 'adj.')
# dark: ('A1', 'adj.')
# date: ('A1', 'n.')
# daughter: ('A1', 'n.')
# day: ('A1', 'n.')
# dear: ('A1', 'adj.')
# december: ('A1', 'n.')
# decide: ('A1', 'v.')
# delicious: ('A1', 'adj.')
# describe: ('A1', 'v.')
# description: ('A1', 'n.')
# design: ('A1', 'n. , v.')
# desk: ('A1', 'n.')
# detail: ('A1', 'n.')
# dialogue: ('A1', 'n.')
# dictionary: ('A1', 'n.')
# die: ('A1', 'v.')
# diet: ('A1', 'n.')
# difference: ('A1', 'n.')
# different: ('A1', 'adj.')
# difficult: ('A1', 'adj.')
# dinner: ('A1', 'n.')
# dirty: ('A1', 'adj.')
# discuss: ('A1', 'v.')
# dish: ('A1', 'n.')
# do1: ('A1', 'v., auxiliary v.')
# doctor: ('A1', 'n.')
# dog: ('A1', 'n.')
# dollar: ('A1', 'n.')
# door: ('A1', 'n.')
# down: ('A1', 'adv. , prep.')
# downstairs: ('A1', 'adv.')
# draw: ('A1', 'v.')
# dress: ('A1', 'n. , v.')
# drink: ('A1', 'n. , v.')
# drive: ('A1', 'v.')
# driver: ('A1', 'n.')
# during: ('A1', 'prep.')
# dvd: ('A1', 'n.')
# each: ('A1', 'det./pron./adv.')
# ear: ('A1', 'n.')
# early: ('A1', 'adj. , adv.')
# east: ('A1', 'n. , adj. , adv.')
# easy: ('A1', 'adj.')
# egg: ('A1', 'n.')
# eight: ('A1', 'number')
# eighteen: ('A1', 'number')
# eighty: ('A1', 'number')
# elephant: ('A1', 'n.')
# eleven: ('A1', 'number')
# else: ('A1', 'adv.')
# email: ('A1', 'n. , v.')
# end: ('A1', 'n. , v.')
# enjoy: ('A1', 'v.')
# enough: ('A1', 'det. , pron. , adv.')
# euro: ('A1', 'n.© Oxford University Press 2 / 12 The Oxford 3000™ by CEFR leveleven adv.')
# even: ('B2', 'adj.')
# evening: ('A1', 'n.')
# event: ('A1', 'n.')
# ever: ('A1', 'adv.')
# every: ('A1', 'det.')
# everybody: ('A1', 'pron.')
# everyone: ('A1', 'pron.')
# everything: ('A1', 'pron.')
# exam: ('A1', 'n.')
# example: ('A1', 'n.')
# excited: ('A1', 'adj.')
# exciting: ('A1', 'adj.')
# exercise: ('A1', 'n. , v.')
# expensive: ('A1', 'adj.')
# explain: ('A1', 'v.')
# extra: ('A1', 'adj.')
# eye: ('A1', 'n.')
# face: ('A1', 'n.')
# fact: ('A1', 'n.')
# fall: ('A1', 'v.')
# false: ('A1', 'adj.')
# family: ('A1', 'n. , adj.')
# famous: ('A1', 'adj.')
# fantastic: ('A1', 'adj.')
# far: ('A1', 'adv.')
# farm: ('A1', 'n.')
# farmer: ('A1', 'n.')
# fast: ('A1', 'adj. , adv.')
# fat: ('A1', 'adj.')
# father: ('A1', 'n.')
# favorite: ('A1', 'adj., n.')
# february: ('A1', 'n.')
# feel: ('A1', 'v.')
# feeling: ('A1', 'n.')
# festival: ('A1', 'n.')
# few: ('A1', 'det./adj. , pron.')
# fifteen: ('A1', 'number')
# fifth: ('A1', 'number')
# fifty: ('A1', 'number')
# fill: ('A1', 'v.')
# final: ('A1', 'adj.')
# find: ('A1', 'v.')
# fine: ('C1', 'n. , v.')
# finish: ('A1', 'v.')
# fire: ('A1', 'n.')
# first: ('A1', 'det./number , adv.')
# fish: ('A1', 'n.')
# five: ('A1', 'number')
# flight: ('A1', 'n.')
# floor: ('A1', 'n.')
# flower: ('A1', 'n.')
# fly: ('A1', 'v.')
# follow: ('A1', 'v.')
# food: ('A1', 'n.')
# foot: ('A1', 'n.')
# football: ('A1', 'n.')
# for: ('A1', 'prep.')
# form: ('A1', 'n. , v.')
# forty: ('A1', 'number')
# four: ('A1', 'number')
# fourteen: ('A1', 'number')
# fourth: ('A1', 'number')
# free: ('A1', 'adj.')
# friday: ('A1', 'n.')
# friend: ('A1', 'n.')
# friendly: ('A1', 'adj.')
# from: ('A1', 'prep.front n. , adj.')
# front: ('A1', 'n., adj.')
# fruit: ('A1', 'n.')
# full: ('A1', 'adj.')
# fun: ('A1', 'n.')
# funny: ('A1', 'adj.')
# future: ('A1', 'n.')
# game: ('A1', 'n.')
# garden: ('A1', 'n.')
# geography: ('A1', 'n.')
# get: ('A1', 'v.')
# girl: ('A1', 'n.')
# girlfriend: ('A1', 'n.')
# give: ('A1', 'v.')
# glass: ('A1', 'n.')
# go: ('A1', 'v.')
# good: ('A1', 'adj.')
# goodbye: ('A1', 'exclam./n.')
# grandfather: ('A1', 'n.')
# grandmother: ('A1', 'n.')
# grandparent: ('A1', 'n.')
# gray: ('A1', 'adj., n.')
# great: ('A1', 'adj.')
# green: ('A1', 'adj. , n.')
# group: ('A1', 'n.')
# grow: ('A1', 'v.')
# guess: ('A1', 'v. , n.')
# guitar: ('A1', 'n.')
# gym: ('A1', 'n.')
# hair: ('A1', 'n.')
# half: ('A1', 'n. , det./pron.')
# hand: ('A1', 'n.')
# happen: ('A1', 'v.')
# happy: ('A1', 'adj.')
# hard: ('A1', 'adj. , adv.')
# hat: ('A1', 'n.')
# hate: ('A1', 'v.')
# have: ('A1', 'v.')
# he: ('A1', 'pron.')
# head: ('A1', 'n.')
# health: ('A1', 'n.')
# healthy: ('A1', 'adj.')
# hear: ('A1', 'v.')
# hello: ('A1', 'exclam./n.')
# help: ('A1', 'v. , n.')
# her: ('A1', 'pron. , det.')
# here: ('A1', 'adv.')
# hey: ('A1', 'exclam.')
# hi: ('A1', 'exclam.')
# high: ('A1', 'adj.')
# him: ('A1', 'pron.')
# his: ('A1', 'det.')
# history: ('A1', 'n.')
# hobby: ('A1', 'n.')
# home: ('A1', 'n. , adv.')
# homework: ('A1', 'n.')
# hope: ('A1', 'v.')
# horse: ('A1', 'n.')
# hospital: ('A1', 'n.')
# hotel: ('A1', 'n.')
# hour: ('A1', 'n.')
# house: ('A1', 'n.')
# how: ('A1', 'adv.')
# however: ('A1', 'adv.')
# hundred: ('A1', 'number')
# hungry: ('A1', 'adj.')
# husband: ('A1', 'n.')
# i: ('A1', 'pron.ice n.')
# ice: ('A1', 'n.')
# idea: ('A1', 'n.')
# if: ('A1', 'conj.')
# imagine: ('A1', 'v.')
# important: ('A1', 'adj.')
# improve: ('A1', 'v.')
# in: ('A1', 'prep. , adv.')
# include: ('A1', 'v.')
# information: ('A1', 'n.')
# interest: ('A1', 'n. , v.')
# interested: ('A1', 'adj.')
# interesting: ('A1', 'adj.')
# internet: ('A1', 'n.')
# interview: ('A1', 'n. , v.')
# into: ('A1', 'prep.')
# introduce: ('A1', 'v.')
# island: ('A1', 'n.')
# it: ('A1', 'pron.')
# its: ('A1', 'det.')
# jacket: ('A1', 'n.')
# january: ('A1', 'n.')
# jeans: ('A1', 'n.')
# job: ('A1', 'n.')
# join: ('A1', 'v.')
# juice: ('A1', 'n.')
# july: ('A1', 'n.')
# june: ('A1', 'n.')
# just: ('C1', 'adj.')
# keep: ('A1', 'v.')
# key: ('A1', 'n. , adj.')
# kind: ('A1', '(type) n.')
# kitchen: ('A1', 'n.')
# know: ('A1', 'v.')
# land: ('A1', 'n.')
# language: ('A1', 'n.')
# large: ('A1', 'adj.')
# last1: ('A1', '(final) det.')
# late: ('A1', 'adj. , adv.')
# later: ('A1', 'adv.')
# laugh: ('A1', 'v. , n.')
# learn: ('A1', 'v.')
# leave: ('A1', 'v.')
# left: ('A1', 'adj. , adv. , n.')
# leg: ('A1', 'n.')
# lesson: ('A1', 'n.')
# let: ('A1', 'v.')
# letter: ('A1', 'n.')
# library: ('A1', 'n.')
# lie1: ('A1', 'v.')
# life: ('A1', 'n.')
# light: ('A1', '(from the sun/a lamp) n. , ')
# like: ('A1', '(similar) prep.')
# line: ('A1', 'n.')
# lion: ('A1', 'n.')
# list: ('A1', 'n. , v.')
# listen: ('A1', 'v.')
# little: ('A1', 'adj. , det./pron.')
# local: ('A1', 'adj.')
# long1: ('A1', 'adj., adv.')
# look: ('A1', 'v.')
# lose: ('A1', 'v.')
# lot: ('A1', 'pron. , det. , adv.')
# love: ('A1', 'n. , v.')
# lunch: ('A1', 'n.machine n.')
# machine: ('A1', 'n.')
# magazine: ('A1', 'n.')
# main: ('A1', 'adj.')
# make: ('A1', 'v.')
# mall: ('A1', 'n. ')
# man: ('A1', 'n.')
# many: ('A1', 'det./pron.')
# map: ('A1', 'n.')
# march: ('C1', 'n. , v.')
# market: ('A1', 'n.')
# married: ('A1', 'adj.')
# match: ('A1', '(contest/correspond) n. , v.')
# may: ('A1', 'n.')
# maybe: ('A1', 'adv.')
# me: ('A1', 'pron.')
# meal: ('A1', 'n.')
# mean: ('A1', 'v.')
# meaning: ('A1', 'n.')
# meat: ('A1', 'n.')
# meet: ('A1', 'v.')
# meeting: ('A1', 'n.')
# member: ('A1', 'n.')
# menu: ('A1', 'n.')
# message: ('A1', 'n.')
# meter: ('A1', 'n.')
# midnight: ('A1', 'n.')
# mile: ('A1', 'n.')
# milk: ('A1', 'n.')
# million: ('A1', 'number')
# minute1: ('A1', 'n.')
# miss: ('A1', 'v.')
# mistake: ('A1', 'n.')
# model: ('A1', 'n.')
# modern: ('A1', 'adj.')
# mom: ('A1', 'n.')
# moment: ('A1', 'n.')
# monday: ('A1', 'n.')
# money: ('A1', 'n.')
# month: ('A1', 'n.')
# more: ('A1', 'det./pron. , adv.')
# morning: ('A1', 'n.')
# most: ('A1', 'det./pron. , adv.')
# mother: ('A1', 'n.')
# mountain: ('A1', 'n.')
# mouse: ('A1', 'n.')
# mouth: ('A1', 'n.')
# move: ('A1', 'v.')
# movie: ('A1', 'n.')
# much: ('A1', 'det./pron. , adv.')
# museum: ('A1', 'n.')
# music: ('A1', 'n.')
# must: ('A1', 'modal v.')
# my: ('A1', 'det.')
# name: ('A1', 'n. , v.')
# natural: ('A1', 'adj.')
# near: ('A1', 'prep. , adj. , adv.')
# need: ('A1', 'v.')
# negative: ('A1', 'adj.')
# neighbor: ('A1', 'n.')
# neighborhood: ('A1', 'n.')
# never: ('A1', 'adv.')
# new: ('A1', 'adj.')
# newspaper: ('A1', 'n.')
# next: ('A1', 'adj. , adv.')
# nice: ('A1', 'adj.')
# night: ('A1', 'n.')
# nine: ('A1', 'number')
# nineteen: ('A1', 'number')
# ninety: ('A1', 'number')
# no: ('A1', 'exclam. , det.© Oxford University Press 3 / 12 The Oxford 3000™ by CEFR levelno\xa0one pron.')
# nobody: ('A1', 'pron.')
# north: ('A1', 'n. , adj. , adv.')
# nose: ('A1', 'n.')
# not: ('A1', 'adv.')
# note: ('A1', 'n.')
# nothing: ('A1', 'pron.')
# november: ('A1', 'n.')
# now: ('A1', 'adv.')
# number: ('A1', 'n.')
# nurse: ('A1', 'n.')
# object: ('A1', 'n.')
# ocean: ('A2', 'n.')
# o’clock: ('A1', 'adv.')
# october: ('A1', 'n.')
# of: ('A1', 'prep.')
# off: ('A1', 'adv. , prep.')
# office: ('A1', 'n.')
# often: ('A1', 'adv.')
# oh: ('A1', 'exclam.')
# ok: ('A1', 'exclam. , adj./adv.')
# old: ('A1', 'adj.')
# on: ('A1', 'prep. , adv.')
# once: ('A1', 'adv.')
# one: ('A1', 'number/det. , pron.')
# onion: ('A1', 'n.')
# online: ('A1', 'adj. , adv.')
# only: ('A1', 'adj. , adv.')
# open: ('A1', 'adj. , v.')
# opinion: ('A1', 'n.')
# opposite: ('A1', 'adj. , n., prep. , adv.')
# or: ('A1', 'conj.')
# orange: ('A1', 'n. , adj.')
# order: ('A1', 'n. , v.')
# other: ('A1', 'adj./pron.')
# our: ('A1', 'det.')
# out: ('A1', 'adv./prep.')
# outside: ('A1', 'adv.')
# over: ('A1', 'prep. , adv.')
# own: ('A1', 'adj./pron.')
# page: ('A1', 'n.')
# paint: ('A1', 'v. , n.')
# painting: ('A1', 'n.')
# pair: ('A1', 'n.')
# pants: ('A2', 'n.')
# paper: ('A1', 'n.')
# paragraph: ('A1', 'n.')
# parent: ('A1', 'n.')
# park: ('A1', 'n. , v.')
# part: ('A1', 'n.')
# partner: ('A1', 'n.')
# party: ('A1', 'n.')
# passport: ('A1', 'n.')
# past: ('A1', 'adj. , n., prep.')
# pay: ('A1', 'v.')
# pen: ('A1', 'n.')
# pencil: ('A1', 'n.')
# people: ('A1', 'n.')
# pepper: ('A1', 'n.')
# perfect: ('A1', 'adj.')
# person: ('A1', 'n.')
# personal: ('A1', 'adj.')
# phone: ('A1', 'n. , v.')
# photo: ('A1', 'n.')
# photograph: ('A1', 'n.')
# phrase: ('A1', 'n.')
# piano: ('A1', 'n.')
# picture: ('A1', 'n.')
# piece: ('A1', 'n.')
# pig: ('A1', 'n.')
# pink: ('A1', 'adj. , n.place n.')
# place: ('B1', 'v.')
# plan: ('A1', 'n. , v.')
# plane: ('A1', 'n.')
# plant: ('A1', 'n.')
# play: ('A1', 'v. , n.')
# player: ('A1', 'n.')
# please: ('A1', 'exclam.')
# point: ('A1', 'n.')
# police: ('A1', 'n.')
# policeman: ('A1', 'n.')
# pool: ('A1', 'n.')
# poor: ('A1', 'adj.')
# popular: ('A1', 'adj.')
# positive: ('A1', 'adj.')
# possible: ('A1', 'adj.')
# post: ('A1', 'n. , v.')
# potato: ('A1', 'n.')
# pound: ('A1', 'n.')
# practice: ('A1', 'n.')
# prefer: ('A1', 'v.')
# prepare: ('A1', 'v.')
# present: ('A1', 'adj. , n.')
# pretty: ('A1', 'adj. , adv.')
# price: ('A1', 'n.')
# probably: ('A1', 'adv.')
# problem: ('A1', 'n.')
# product: ('A1', 'n.')
# program: ('A2', 'n.progress n.')
# project: ('A1', 'n.')
# purple: ('A1', 'adj. , n.')
# put: ('A1', 'v.')
# quarter: ('A1', 'n.')
# question: ('A1', 'n.')
# quick: ('A1', 'adj.')
# quickly: ('A1', 'adv.')
# quiet: ('A1', 'adj.')
# quite: ('A1', 'adv.')
# radio: ('A1', 'n.')
# rain: ('A1', 'n. , v.')
# read: ('A1', 'v.')
# reader: ('A1', 'n.')
# reading: ('A1', 'n.')
# ready: ('A1', 'adj.')
# real: ('A1', 'adj.')
# really: ('A1', 'adv.')
# reason: ('A1', 'n.')
# red: ('A1', 'adj. , n.')
# relax: ('A1', 'v.')
# remember: ('A1', 'v.')
# repeat: ('A1', 'v.')
# report: ('A1', 'n.')
# restaurant: ('A1', 'n.')
# result: ('A1', 'n.')
# return: ('A1', 'v. , n.')
# rice: ('A1', 'n.')
# rich: ('A1', 'adj.')
# ride: ('A1', 'v.')
# right: ('A1', 'adj. , adv. , n.')
# road: ('A1', 'n.')
# room: ('A1', 'n.')
# routine: ('A1', 'n.')
# rule: ('A1', 'n.')
# run: ('A1', 'v.')
# sad: ('A1', 'adj.')
# salad: ('A1', 'n.')
# salt: ('A1', 'n.')
# same: ('A1', 'adj. , pron. , adv.')
# sandwich: ('A1', 'n.Saturday n.')
# saturday: ('A1', 'n.')
# say: ('C1', 'n.')
# school: ('A1', 'n.')
# science: ('A1', 'n.')
# scientist: ('A1', 'n.')
# second1: ('A1', '(next after the first)  ')
# section: ('A1', 'n.')
# see: ('A1', 'v.')
# sell: ('A1', 'v.')
# send: ('A1', 'v.')
# sentence: ('A1', 'n.')
# september: ('A1', 'n.')
# seven: ('A1', 'number')
# seventeen: ('A1', 'number')
# seventy: ('A1', 'number')
# share: ('A1', 'v.')
# she: ('A1', 'pron.')
# sheep: ('A1', 'n.')
# shirt: ('A1', 'n.')
# shoe: ('A1', 'n.')
# shop: ('A1', 'n. , v.')
# shopping: ('A1', 'n.')
# short: ('A1', 'adj.')
# should: ('A1', 'modal v.')
# show: ('A1', 'v. , n.')
# shower: ('A1', 'n.')
# sick: ('A1', 'adj.')
# similar: ('A1', 'adj.')
# sing: ('A1', 'v.')
# singer: ('A1', 'n.')
# sister: ('A1', 'n.')
# sit: ('A1', 'v.')
# situation: ('A1', 'n.')
# six: ('A1', 'number')
# sixteen: ('A1', 'number')
# sixty: ('A1', 'number')
# skill: ('A1', 'n.')
# skirt: ('A1', 'n.')
# sleep: ('A1', 'v.')
# slow: ('A1', 'adj.')
# small: ('A1', 'adj.')
# smart: ('B1', 'adj.')
# snake: ('A1', 'n.')
# snow: ('A1', 'n. , v.')
# so: ('A1', 'adv. , conj.')
# some: ('A1', 'det. , pron.')
# somebody: ('A1', 'pron.')
# someone: ('A1', 'pron.')
# something: ('A1', 'pron.')
# sometimes: ('A1', 'adv.')
# son: ('A1', 'n.')
# song: ('A1', 'n.')
# soon: ('A1', 'adv.')
# sorry: ('A1', 'adj. , exclam.')
# sound: ('C1', 'adj.sovereignty n.spam n.span v. , n.')
# soup: ('A1', 'n.')
# south: ('A1', 'n. , adj. , adv.')
# speak: ('A1', 'v.')
# special: ('A1', 'adj.')
# spell: ('A1', 'v.')
# spelling: ('A1', 'n.')
# spend: ('A1', 'v.')
# sport: ('A1', 'n.')
# spring: ('A1', 'n.')
# stand: ('A1', 'v.')
# star: ('A1', 'n.')
# start: ('A1', 'v.statement n.')
# statement: ('A1', 'n.')
# station: ('A1', 'n.')
# stay: ('A1', 'v.')
# still: ('A1', 'adv.')
# stop: ('A1', 'v. , n.')
# store: ('A2', 'n.')
# story: ('A1', 'n.')
# street: ('A1', 'n.')
# strong: ('A1', 'adj.')
# student: ('A1', 'n.')
# study: ('A1', 'n. , v.')
# style: ('A1', 'n.')
# subject: ('A1', 'n.')
# success: ('A1', 'n.')
# sugar: ('A1', 'n.')
# summer: ('A1', 'n.')
# sun: ('A1', 'n.')
# sunday: ('A1', 'n.')
# supermarket: ('A1', 'n.')
# sure: ('A1', 'adj.')
# sweater: ('A1', 'n.')
# swim: ('A1', 'v.')
# swimming: ('A1', 'n.')
# table: ('A1', 'n.')
# take: ('A1', 'v.')
# talk: ('A1', 'v.')
# tall: ('A1', 'adj.')
# taxi: ('A1', 'n.')
# tea: ('A1', 'n.')
# teach: ('A1', 'v.')
# teacher: ('A1', 'n.')
# team: ('A1', 'n.')
# teenager: ('A1', 'n.')
# telephone: ('A1', 'n. , v.')
# television: ('A1', 'n.')
# tell: ('A1', 'v.')
# ten: ('A1', 'number')
# tennis: ('A1', 'n.')
# terrible: ('A1', 'adj.')
# test: ('A1', 'n. , v.')
# text: ('A1', 'n.')
# than: ('A1', 'conj.')
# thank: ('A1', 'v.')
# thanks: ('A1', 'exclam. , n.')
# that: ('A1', 'det. , pron. , conj.')
# the: ('A1', 'definite article')
# theater: ('A1', 'n.')
# their: ('A1', 'det.')
# them: ('A1', 'pron.')
# then: ('A1', 'adv.')
# there: ('A1', 'adv.')
# they: ('A1', 'pron.')
# thing: ('A1', 'n.')
# think: ('A1', 'v.')
# third: ('A1', 'number')
# thirsty: ('A1', 'adj.')
# thirteen: ('A1', 'number')
# thirty: ('A1', 'number')
# this: ('A1', 'det./pron.')
# three: ('A1', 'number')
# through: ('A1', 'prep. , adv.')
# thursday: ('A1', 'n.')
# ticket: ('A1', 'n.')
# time: ('A1', 'n.')
# tired: ('A1', 'adj.')
# title: ('A1', 'n.')
# to: ('A1', 'prep. , infinitive marker')
# today: ('A1', 'adv. , n.')
# together: ('A1', 'adv.')
# toilet: ('A1', 'n.© Oxford University Press 4 / 12 The Oxford 3000™ by CEFR leveltomato n.')
# tomato: ('A1', 'n.')
# tomorrow: ('A1', 'adv. , n.')
# tonight: ('A1', 'adv. , n.')
# too: ('A1', 'adv.')
# tooth: ('A1', 'n.')
# topic: ('A1', 'n.')
# tourist: ('A1', 'n.')
# town: ('A1', 'n.')
# traffic: ('A1', 'n.')
# train: ('A1', 'n.')
# travel: ('A1', 'v. , n.')
# tree: ('A1', 'n.')
# trip: ('A1', 'n.')
# truck: ('A2', 'n.')
# true: ('A1', 'adj.')
# try: ('A1', 'v.')
# t-shirt: ('A1', 'n.')
# tuesday: ('A1', 'n.')
# turn: ('A1', 'v. , n.')
# tv: ('A1', 'n.')
# twelve: ('A1', 'number')
# twenty: ('A1', 'number')
# twice: ('A1', 'adv.')
# two: ('A1', 'number')
# type: ('A1', 'n.')
# umbrella: ('A1', 'n.')
# uncle: ('A1', 'n.')
# under: ('A1', 'prep. , adv.')
# understand: ('A1', 'v.')
# university: ('A1', 'n.')
# until: ('A1', 'conj./prep.')
# up: ('A1', 'adv. , prep.')
# upstairs: ('A1', 'adv.')
# us: ('A1', 'pron.')
# use: ('A1', 'v.')
# useful: ('A1', 'adj.')
# usually: ('A1', 'adv.')
# vacation: ('A1', 'n.')
# vegetable: ('A1', 'n.')
# very: ('A1', 'adv.')
# video: ('A1', 'n.')
# visit: ('A1', 'v. , n.')
# visitor: ('A1', 'n.')
# wait: ('A1', 'v.')
# waiter: ('A1', 'n.')
# wake: ('A1', 'v.')
# walk: ('A1', 'v. , n.')
# wall: ('A1', 'n.')
# want: ('A1', 'v.')
# warm: ('A1', 'adj.')
# wash: ('A1', 'v.')
# watch: ('A1', 'v. , n.')
# water: ('A1', 'n.')
# way: ('A1', 'n.')
# we: ('A1', 'pron.')
# wear: ('A1', 'v.')
# weather: ('A1', 'n.')
# website: ('A1', 'n.')
# week: ('A1', 'n.')
# weekend: ('A1', 'n.')
# welcome: ('A1', 'exclam. , v., adj.')
# well: ('C1', 'n.')
# west: ('A1', 'n. , adj. , adv.')
# what: ('A1', 'pron./det.')
# when: ('A1', 'adv. , pron. , conj.')
# where: ('A1', 'adv. , conj.')
# which: ('A1', 'pron./det.')
# white: ('A1', 'adj. , n.who pron.')
# who: ('A1', 'pron.')
# why: ('A1', 'adv.')
# wife: ('A1', 'n.')
# will: ('A1', 'modal v.')
# win: ('A1', 'v.')
# window: ('A1', 'n.')
# wine: ('A1', 'n.')
# winter: ('A1', 'n.')
# with: ('A1', 'prep.')
# without: ('A1', 'prep.')
# woman: ('A1', 'n.')
# wonderful: ('A1', 'adj.')
# word: ('A1', 'n.')
# work: ('A1', 'v. , n.')
# worker: ('A1', 'n.')
# world: ('A1', 'n.')
# would: ('A1', 'modal v.')
# write: ('A1', 'v.')
# writer: ('A1', 'n.')
# writing: ('A1', 'n.')
# wrong: ('A1', 'adj.')
# yard: ('B1', 'n.')
# yeah: ('A1', 'exclam.')
# year: ('A1', 'n.')
# yellow: ('A1', 'adj. , n.')
# yes: ('A1', 'exclam.')
# yesterday: ('A1', 'adv. , n.')
# you: ('A1', 'pron.')
# young: ('A1', 'adj.')
# your: ('A1', 'det.')
# yourself: ('A1', 'pron.')
# ability: ('A2', 'n.')
# able: ('A2', 'adj.')
# accept: ('A2', 'v.')
# accident: ('A2', 'n.')
# according: ('A2', 'to  prep.')
# achieve: ('A2', 'v.')
# act: ('A2', 'v.')
# active: ('A2', 'adj.')
# actually: ('A2', 'adv.')
# advantage: ('A2', 'n.')
# adventure: ('A2', 'n.')
# advertise: ('A2', 'v.')
# advertisement: ('A2', 'n.')
# advertising: ('A2', 'n.')
# affect: ('A2', 'v.')
# against: ('A2', 'prep.')
# ah: ('A2', 'exclam.')
# airline: ('A2', 'n.')
# alive: ('A2', 'adj.')
# allow: ('A2', 'v.')
# alone: ('A2', 'adj./adv.')
# along: ('A2', 'prep. , adv.')
# already: ('A2', 'adv.')
# alternative: ('A2', 'n.')
# although: ('A2', 'conj.')
# among: ('A2', 'prep.')
# amount: ('A2', 'n.')
# analyze: ('A2', 'v.')
# ancient: ('A2', 'adj.')
# ankle: ('A2', 'n.')
# anybody: ('A2', 'pron.')
# anymore: ('A2', 'adv.')
# anyway: ('A2', 'adv.')
# anywhere: ('A2', 'adv. , pron.')
# app: ('A2', 'n.')
# appear: ('A2', 'v.')
# appearance: ('A2', 'n.')
# apply: ('A2', 'v.')
# architect: ('A2', 'n.')
# architecture: ('A2', 'n.')
# argue: ('A2', 'v.')
# argument: ('A2', 'n.')
# army: ('A2', 'n.')
# arrange: ('A2', 'v.')
# arrangement: ('A2', 'n.')
# asleep: ('A2', 'adj.')
# assistant: ('A2', 'n. , adj.')
# athlete: ('A2', 'n.')
# attack: ('A2', 'n. , v.')
# attend: ('A2', 'v.')
# attention: ('A2', 'n. , exclam.')
# attractive: ('A2', 'adj.')
# audience: ('A2', 'n.')
# author: ('A2', 'n.')
# available: ('A2', 'adj.')
# average: ('A2', 'adj. , n.')
# avoid: ('A2', 'v.')
# award: ('A2', 'n.')
# awful: ('A2', 'adj.')
# background: ('A2', 'n.')
# badly: ('A2', 'adv.')
# based: ('A2', 'adj.')
# bean: ('A2', 'n.')
# bear: ('A2', '(animal) n.')
# beat: ('A2', 'v.')
# beef: ('A2', 'n.')
# behave: ('A2', 'v.')
# behavior: ('A2', 'n.')
# belong: ('A2', 'v.')
# belt: ('A2', 'n.')
# benefit: ('A2', 'n.')
# billion: ('A2', 'number')
# biology: ('A2', 'n.')
# birth: ('A2', 'n.')
# bit: ('A2', 'n.')
# blank: ('A2', 'adj. , n.')
# block: ('B1', 'n. , v.')
# blood: ('A2', 'n.')
# blow: ('B2', 'n.')
# board: ('A2', 'n.')
# boil: ('A2', 'v.')
# bone: ('A2', 'n.')
# borrow: ('A2', 'v.')
# boss: ('A2', 'n.')
# bottom: ('A2', 'n. , adj.')
# bowl: ('A2', 'n.')
# brain: ('A2', 'n.')
# bridge: ('A2', 'n.')
# bright: ('A2', 'adj.brilliant adj.')
# brilliant: ('A2', 'adj.')
# broken: ('A2', 'adj.')
# brush: ('A2', 'v. , n.')
# burn: ('A2', 'v.')
# businessman: ('A2', 'n.')
# button: ('A2', 'n.')
# camp: ('A2', 'n. , v.')
# camping: ('A2', 'n.')
# campus: ('B1', 'n.')
# can2: ('A2', 'n.')
# candy: ('A2', 'n.')
# care: ('A2', 'n. , v.')
# careful: ('A2', 'adj.')
# carefully: ('A2', 'adv.')
# carpet: ('A2', 'n.')
# cartoon: ('A2', 'n.')
# case: ('A2', 'n.')
# cash: ('A2', 'n.')
# catch: ('A2', 'v.')
# cause: ('A2', 'n. , v.')
# celebrate: ('A2', 'v.')
# celebrity: ('A2', 'n.')
# cell: ('B2', 'n.')
# century: ('A1', 'n.')
# certain: ('A2', 'adj.')
# certainly: ('A2', 'adv.')
# chance: ('A2', 'n.')
# character: ('A2', 'n.')
# charity: ('A2', 'n.')
# chat: ('A2', 'v. , n.')
# chef: ('A2', 'n.')
# chemistry: ('A2', 'n.')
# chip: ('A2', 'n.')
# choice: ('A2', 'n.')
# church: ('A2', 'n.')
# cigarette: ('A2', 'n.')
# circle: ('A2', 'n. , v.')
# classical: ('A2', 'adj.')
# clear: ('A2', 'adj.')
# clearly: ('A2', 'adv.')
# clerk: ('B2', 'n.')
# climate: ('A2', 'n.')
# close2: ('A2', 'adj.')
# closed: ('A2', 'adj.')
# closet: ('A2', 'n.')
# clothing: ('A2', 'n.')
# cloud: ('A2', 'n.')
# coach: ('A2', 'n.')
# coast: ('A2', 'n.')
# code: ('A2', 'n.')
# colleague: ('A2', 'n.')
# collect: ('A2', 'v.')
# column: ('A2', 'n.')
# comedy: ('A2', 'n.')
# comfortable: ('A2', 'adj.')
# comment: ('A2', 'n.')
# communicate: ('A2', 'v.')
# community: ('A2', 'n.')
# compete: ('A2', 'v.')
# competition: ('A2', 'n.')
# complain: ('A2', 'v.')
# condition: ('A2', 'n.')
# conference: ('A2', 'n.')
# connect: ('A2', 'v.')
# connected: ('A2', 'adj.')
# consider: ('A2', 'v.')
# contain: ('A2', 'v.')
# context: ('A2', 'n.')
# continent: ('A2', 'n.')
# continue: ('A2', 'v.')
# control: ('A2', 'n. , v.')
# cookie: ('A2', 'n.')
# copy: ('A2', 'n. , v.')
# corner: ('A2', 'n.')
# correctly: ('A2', 'adv.')
# count: ('A2', 'v.')
# couple: ('A2', 'n.')
# cover: ('A2', 'v.')
# crazy: ('A2', 'adj.')
# creative: ('A2', 'adj.')
# credit: ('A2', 'n.')
# crime: ('A2', 'n.')
# criminal: ('A2', 'n.')
# cross: ('A2', 'v. , n.')
# crowd: ('A2', 'n.')
# crowded: ('A2', 'adj.')
# cry: ('A2', 'v.')
# curly: ('A2', 'adj.')
# cycle: ('A2', 'n. , v.')
# daily: ('A2', 'adj.')
# danger: ('A2', 'n.')
# data: ('A2', 'n.')
# dead: ('A2', 'adj.')
# deal: ('A2', 'v.')
# death: ('A2', 'n.')
# decision: ('A2', 'n.')
# deep: ('A2', 'adj.')
# definitely: ('A2', 'adv.')
# degree: ('A2', 'n.')
# dentist: ('A2', 'n.')
# department: ('A2', 'n.')
# depend: ('A2', 'v.')
# desert: ('A2', 'n.')
# designer: ('A2', 'n.')
# dessert: ('A2', 'n.')
# destroy: ('A2', 'v.')
# detective: ('A2', 'n.')
# develop: ('A2', 'v.')
# device: ('A2', 'n.')
# diary: ('A2', 'n.')
# differently: ('A2', 'adv.')
# digital: ('A2', 'adj.')
# direct: ('A2', 'adj.')
# direction: ('A2', 'n.')
# director: ('A2', 'n.')
# disagree: ('A2', 'v.')
# disappear: ('A2', 'v.')
# disaster: ('A2', 'n.')
# discover: ('A2', 'v.')
# discovery: ('A2', 'n.')
# discussion: ('A2', 'n.')
# disease: ('A2', 'n.')
# distance: ('A2', 'n.')
# divorced: ('A2', 'adj.')
# document: ('A2', 'n.')
# double: ('A2', 'adj. , det. , pron. , v.')
# download: ('A2', 'v. , n.')
# drama: ('A2', 'n.')
# drawing: ('A2', 'n.')
# dream: ('A2', 'n. , v.')
# driving: ('C1', 'adj.')
# drop: ('A2', 'v.')
# drug: ('A2', 'n.')
# dry: ('A2', 'adj. , v.')
# earn: ('A2', 'v.')
# earth: ('A2', 'n.')
# easily: ('A2', 'adv.education n.')
# education: ('A2', 'n.')
# effect: ('A2', 'n.')
# either: ('A2', 'det./pron. , adv.')
# electric: ('A2', 'adj.')
# electrical: ('A2', 'adj.')
# electricity: ('A2', 'n.')
# electronic: ('A2', 'adj.')
# elevator: ('A2', 'n.')
# employ: ('A2', 'v.')
# employee: ('A2', 'n.')
# employer: ('A2', 'n.')
# empty: ('A2', 'adj.')
# ending: ('A2', 'n.')
# energy: ('A2', 'n.')
# engine: ('A2', 'n.')
# engineer: ('A2', 'n.')
# enormous: ('A2', 'adj.')
# enter: ('A2', 'v.')
# environment: ('A2', 'n.')
# equipment: ('A2', 'n.')
# error: ('A2', 'n.')
# especially: ('A2', 'adv.')
# essay: ('A2', 'n.')
# everyday: ('A2', 'adj.')
# everywhere: ('A2', 'adv.')
# evidence: ('A2', 'n.')
# exact: ('A2', 'adj.')
# exactly: ('A2', 'adv.')
# excellent: ('A2', 'adj.')
# except: ('A2', 'prep.')
# exist: ('A2', 'v.')
# expect: ('A2', 'v.')
# experience: ('A2', 'n.')
# experiment: ('A2', 'n.')
# expert: ('A2', 'n.,adj.')
# explanation: ('A2', 'n.')
# express: ('A2', 'v.')
# expression: ('A2', 'n.')
# extreme: ('A2', 'adj.')
# extremely: ('A2', 'adv.')
# factor: ('A2', 'n.')
# factory: ('A2', 'n.')
# fail: ('A2', 'v.')
# fair: ('A2', 'adj.')
# fan: ('A2', 'n.')
# farming: ('A2', 'n.')
# fashion: ('A2', 'n.')
# fear: ('A2', 'n.')
# feature: ('A2', 'n.')
# feed: ('A2', 'v.')
# female: ('A2', 'adj. , n.')
# fever: ('B2', 'n.')
# fiction: ('A2', 'n.')
# field: ('A2', 'n.')
# fight: ('A2', 'v. , n.')
# figure: ('A2', 'n.')
# finally: ('A2', 'adv.')
# finger: ('A2', 'n.')
# fishing: ('A2', 'n.')
# fit: ('C1', 'n.')
# fix: ('A2', 'v.')
# flat: ('A1', 'n.')
# flu: ('A2', 'n.fly n.')
# flying: ('A2', 'n. , adj.')
# focus: ('A2', 'v. , n.')
# following: ('A2', 'adj.')
# foreign: ('A2', 'adj.')
# forest: ('A2', 'n.')
# fork: ('A2', 'n.')
# formal: ('A2', 'adj.')
# fortunately: ('A2', 'adv.')
# forward: ('A2', 'adv.')
# fresh: ('A2', 'adj.')
# frog: ('A2', 'n.')
# furniture: ('A2', 'n.')
# further: ('A2', 'adj.')
# gallery: ('A2', 'n.')
# gap: ('A2', 'n.')
# garbage: ('A2', 'n.')
# gas: ('A2', 'n.')
# gate: ('A2', 'n.')
# general: ('A2', 'adj.')
# gift: ('A2', 'n.')
# goal: ('A2', 'n.')
# god: ('A2', 'n.')
# gold: ('A2', 'n. , adj.')
# golf: ('A2', 'n.')
# government: ('A2', 'n.')
# grass: ('A2', 'n.')
# greet: ('A2', 'v.')
# grocery: ('B2', 'n.')
# ground: ('A2', 'n.')
# guest: ('A2', 'n.')
# guide: ('A2', 'n. , v.')
# gun: ('A2', 'n.')
# guy: ('A2', 'n.')
# habit: ('A2', 'n.')
# hall: ('A2', 'n.')
# happily: ('A2', 'adv.')
# headache: ('A2', 'n.')
# heart: ('A2', 'n.')
# heat: ('A2', 'n. , v.')
# heavy: ('A2', 'adj.')
# height: ('A2', 'n.')
# helpful: ('A2', 'adj.')
# hero: ('A2', 'n.')
# hers: ('A2', 'pron.')
# herself: ('A2', 'pron.')
# hide: ('A2', 'v.')
# hill: ('A2', 'n.')
# himself: ('A2', 'pron.')
# hockey: ('A2', 'n.')
# hold: ('A2', 'v.')
# hole: ('A2', 'n.')
# holiday: ('A1', 'n.')
# huge: ('A2', 'adj.')
# human: ('A2', 'adj. , n.')
# hurt: ('A2', 'v. , adj.')
# ideal: ('A2', 'adj.')
# identify: ('A2', 'v.')
# ill: ('A2', 'adj.')
# illness: ('A2', 'n.')
# image: ('A2', 'n.immediately adv.')
# immediately: ('A2', 'adv.')
# impossible: ('A2', 'adj.')
# included: ('A2', 'adj.')
# including: ('A2', 'prep.')
# increase: ('A2', 'v. , n.')
# incredible: ('A2', 'adj.')
# independent: ('A2', 'adj.')
# individual: ('A2', 'n. , adj.')
# industry: ('A2', 'n.')
# informal: ('A2', 'adj.')
# injury: ('A2', 'n.')
# insect: ('A2', 'n.')
# inside: ('A2', 'prep. , adv. , n., adj.')
# instead: ('A2', 'adv.')
# instruction: ('A2', 'n.')
# instructor: ('A2', 'n.')
# instrument: ('A2', 'n.')
# intelligent: ('A2', 'adj.')
# international: ('A2', 'adj.')
# introduction: ('A2', 'n.')
# invent: ('A2', 'v.')
# invention: ('A2', 'n.')
# invitation: ('A2', 'n.')
# invite: ('A2', 'v.')
# involve: ('A2', 'v.')
# item: ('A2', 'n.')
# itself: ('A2', 'pron.')
# jam: ('A2', 'n.')
# jazz: ('A2', 'n.')
# jewelry: ('A2', 'n.')
# joke: ('A2', 'n. , v.')
# journalist: ('A2', 'n.')
# jump: ('A2', 'v. , n.')
# kid: ('A2', 'n.')
# kill: ('A2', 'v.')
# kilometer: ('A2', 'n.')
# king: ('A2', 'n.')
# knee: ('A2', 'n.')
# knife: ('A2', 'n.')
# knock: ('A2', 'v.')
# knowledge: ('A2', 'n.')
# lab: ('A2', 'n.')
# lady: ('A2', 'n.')
# lake: ('A2', 'n.')
# lamp: ('A2', 'n.')
# laptop: ('A2', 'n.')
# laughter: ('A2', 'n.')
# law: ('A2', 'n.')
# lawyer: ('A2', 'n.')
# lazy: ('A2', 'adj.')
# lead1: ('A2', 'v.© Oxford University Press 6 / 13 The Oxford 3000™ by CEFR level (American English) leader n.')
# learning: ('A2', 'n.')
# least: ('A2', 'det./pron. , adv.')
# lecture: ('A2', 'n. , v.')
# lemon: ('A2', 'n.')
# lend: ('A2', 'v.')
# less: ('A2', 'det./pron. , adv.')
# level: ('A2', 'n.')
# lifestyle: ('A2', 'n.')
# lift: ('A2', 'v. , n.')
# likely: ('A2', 'adj.')
# link: ('A2', 'n. , v.')
# listener: ('A2', 'n.')
# lock: ('A2', 'v., n.')
# lost: ('A2', 'adj.')
# loud: ('A2', 'adj. , adv.')
# loudly: ('A2', 'adv.')
# low: ('A2', 'adj. , adv.')
# luck: ('A2', 'n.')
# lucky: ('A2', 'adj.')
# mail: ('A2', 'n. , v.')
# major: ('A2', 'adj.')
# male: ('A2', 'adj. , n.')
# manage: ('A2', 'v.')
# manager: ('A2', 'n.')
# manner: ('A2', 'n.')
# mark: ('A2', 'v. , n.')
# marry: ('A2', 'v.')
# material: ('A2', 'n.')
# math: ('A2', 'n.')
# mathematics: ('A2', 'n.')
# matter: ('A2', 'n. , v.')
# mayor: ('B2', 'n.')
# media: ('A2', 'n.')
# medical: ('A2', 'adj.')
# medicine: ('A2', 'n.')
# memory: ('A2', 'n.')
# mention: ('A2', 'v.')
# metal: ('A2', 'n.')
# method: ('A2', 'n.')
# middle: ('A2', 'n. , adj.')
# might: ('A2', 'modal v.')
# mind: ('A2', 'n. , v.')
# mine: ('A2', '(belongs to me) pron.')
# mirror: ('A2', 'n.')
# missing: ('A2', 'adj.')
# monkey: ('A2', 'n.')
# moon: ('A2', 'n.')
# mostly: ('A2', 'adv.')
# motorcycle: ('A2', 'n.')
# movement: ('A2', 'n.')
# musical: ('A2', 'adj.')
# musician: ('A2', 'n.')
# myself: ('A2', 'pron.')
# narrow: ('A2', 'adj.')
# national: ('A2', 'adj.')
# nature: ('A2', 'n.')
# nearly: ('A2', 'adv.')
# necessary: ('A2', 'adj.')
# neck: ('A2', 'n.')
# neither: ('A2', 'det./pron.')
# nervous: ('A2', 'adj.')
# network: ('A2', 'n.')
# noise: ('A2', 'n.')
# none: ('A2', 'pron.')
# normal: ('A2', 'adj.')
# normally: ('A2', 'adv.')
# notice: ('A2', 'v. , n.')
# novel: ('C1', 'adj.')
# nowhere: ('A2', 'adv.')
# nut: ('A2', 'n.')
# offer: ('A2', 'v. , n.')
# officer: ('A2', 'n.')
# oil: ('A2', 'n.')
# onto: ('A2', 'prep.opportunity n.')
# opportunity: ('A2', 'n.')
# option: ('A2', 'n.')
# ordinary: ('A2', 'adj.')
# organization: ('A2', 'n.')
# organize: ('A2', 'v.')
# original: ('A2', 'adj.')
# ourselves: ('A2', 'pron.')
# oven: ('A2', 'n.')
# overseas: ('B2', 'adv. , adj.')
# owner: ('A2', 'n.')
# pack: ('A2', 'v.')
# pain: ('A2', 'n.')
# painter: ('A2', 'n.')
# palace: ('A2', 'n.')
# parking: ('A2', 'n.')
# particular: ('A2', 'adj.')
# pass: ('A2', 'v.')
# passenger: ('A2', 'n.')
# patient: ('A2', 'n.')
# pattern: ('A2', 'n.')
# peace: ('A2', 'n.')
# penny: ('A2', 'n.')
# per: ('A2', 'prep.')
# percent: ('A2', 'noun., adj./adv.')
# perform: ('A2', 'v.')
# perhaps: ('A2', 'adv.')
# permission: ('A2', 'n.')
# personality: ('A2', 'n.')
# pet: ('A2', 'n.')
# physical: ('A2', 'adj.')
# physics: ('A2', 'n.')
# pick: ('A2', 'v.')
# pilot: ('A2', 'n.')
# planet: ('A2', 'n.')
# plastic: ('A2', 'n. , adj.')
# plate: ('A2', 'n.')
# platform: ('A2', 'n.')
# pleased: ('A2', 'adj.')
# pocket: ('A2', 'n.')
# polite: ('A2', 'adj.')
# pollution: ('A2', 'n.')
# pop: ('C1', 'v.')
# population: ('A2', 'n.')
# position: ('A2', 'n.')
# possession: ('A2', 'n.')
# possibility: ('A2', 'n.')
# poster: ('A2', 'n.')
# power: ('A2', 'n.')
# predict: ('A2', 'v.')
# prevent: ('A2', 'v.')
# print: ('A2', 'v.')
# printer: ('A2', 'n.')
# prison: ('A2', 'n.')
# prize: ('A2', 'n.')
# process: ('A2', 'n.')
# produce: ('A2', 'v.')
# professional: ('A2', 'adj.')
# professor: ('A2', 'n.')
# profile: ('A2', 'n.')
# progress: ('B2', 'v.')
# promise: ('A2', 'v. , n.')
# pronounce: ('A2', 'v.')
# protect: ('A2', 'v.')
# provide: ('A2', 'v.')
# public: ('A2', 'adj. , n.')
# publish: ('A2', 'v.')
# pull: ('A2', 'v.')
# purpose: ('A2', 'n.')
# push: ('A2', 'v.')
# quality: ('A2', 'n.')
# quantity: ('A2', 'n.')
# queen: ('A2', 'n.')
# quietly: ('A2', 'adv.')
# race: ('A2', '(competition) n. , v.')
# railroad: ('A2', 'n.')
# raise: ('A2', 'v.')
# rate: ('A2', 'n.')
# rather: ('A2', 'adv.')
# reach: ('A2', 'v.')
# react: ('A2', 'v.')
# realize: ('A2', 'v.')
# receive: ('A2', 'v.')
# recent: ('A2', 'adj.')
# recently: ('A2', 'adv.')
# reception: ('A2', 'n.')
# recipe: ('A2', 'n.')
# recognize: ('A2', 'v.')
# recommend: ('A2', 'v.')
# record: ('A2', 'n. , v.')
# recording: ('A2', 'n.')
# recycle: ('A2', 'v.')
# reduce: ('A2', 'v.')
# refer: ('A2', 'v.')
# refrigerator: ('A2', 'n.')
# refuse1: ('A2', 'v.')
# region: ('A2', 'n.')
# regular: ('A2', 'adj.')
# relationship: ('A2', 'n.')
# remove: ('A2', 'v.')
# repair: ('A2', 'v.')
# replace: ('A2', 'v.')
# reply: ('A2', 'v. , n.')
# reporter: ('A2', 'n.')
# request: ('A2', 'n.')
# research: ('A2', 'n. , v.')
# researcher: ('A2', 'n.')
# respond: ('A2', 'v.')
# response: ('A2', 'n.')
# rest: ('A2', '(remaining part) n.')
# review: ('A2', 'n. , v.')
# ring1: ('A2', 'n.')
# ring2: ('A2', 'v.')
# rise: ('A2', 'v.')
# rock: ('C1', 'v.')
# role: ('A2', 'n.')
# roof: ('A2', 'n.')
# round: ('A2', 'adj. , adv. , prep.')
# route: ('A2', 'n.')
# rude: ('A2', 'adj.')
# runner: ('A2', 'n.')
# running: ('A2', 'n.')
# sadly: ('A2', 'adv.safe adj.')
# safe: ('A2', 'adj.')
# sail: ('A2', 'v.')
# sailing: ('A2', 'n.')
# salary: ('A2', 'n.')
# sale: ('A2', 'n.')
# sauce: ('A2', 'n.')
# save: ('A2', 'v.')
# scared: ('A2', 'adj.')
# scary: ('A2', 'adj.')
# scene: ('A2', 'n.')
# schedule: ('A2', 'n.')
# score: ('A2', 'v. , n.')
# screen: ('A2', 'n.')
# sea: ('A1', 'n.')
# search: ('A2', 'n. , v.')
# season: ('A2', 'n.')
# seat: ('A2', 'n.')
# secret: ('A2', 'adj. , n.')
# secretary: ('A2', 'n.')
# seem: ('A2', 'v.')
# sense: ('A2', 'n.')
# separate: ('A2', 'adj.')
# series: ('A2', 'n.')
# serious: ('A2', 'adj.')
# serve: ('A2', 'v.')
# service: ('A2', 'n.')
# several: ('A2', 'det./pron.')
# shake: ('A2', 'v.')
# shape: ('A2', 'n.')
# sheet: ('A2', 'n.')
# ship: ('A2', 'n.')
# shoulder: ('A2', 'n.')
# shout: ('A2', 'v. , n.')
# shut: ('A2', 'v. , adj.')
# side: ('A2', 'n.')
# sign: ('A2', 'n. , v.')
# silver: ('A2', 'n. , adj.')
# simple: ('A2', 'adj.')
# since: ('A2', 'prep. , conj.')
# singing: ('A2', 'n.')
# single: ('A2', 'adj. , n.')
# sir: ('A2', 'n.')
# site: ('A2', 'n.')
# size: ('A2', 'n.')
# ski: ('A2', 'v. , adj. , n.')
# skiing: ('A2', 'n.')
# skin: ('A2', 'n.')
# sky: ('A2', 'n.')
# slowly: ('A2', 'adv.')
# smartphone: ('A2', 'n. ')
# smell: ('A2', 'v. , n.')
# smile: ('A2', 'v. , n.')
# smoke: ('A2', 'n. , v.')
# smoking: ('A2', 'n.')
# sneaker: ('A2', 'n.')
# soap: ('A2', 'n.')
# soccer: ('A2', 'n.')
# social: ('A2', 'adj.')
# sock: ('A2', 'n.')
# soft: ('A2', 'adj.')
# soldier: ('A2', 'n.')
# solution: ('A2', 'n.')
# solve: ('A2', 'v.')
# somewhere: ('A2', 'adv. , pron.')
# sort: ('A2', 'n.')
# source: ('A2', 'n.')
# speaker: ('A2', 'n.© Oxford University Press 7 / 12 The Oxford 3000™ by CEFR levelspecific adj.')
# specific: ('A2', 'adj.')
# speech: ('A2', 'n.')
# speed: ('A2', 'n.')
# spider: ('A2', 'n.')
# spoon: ('A2', 'n.')
# square: ('A2', 'adj. , n.')
# stage: ('A2', 'n.')
# stair: ('A2', 'n.')
# stamp: ('A2', 'n.')
# state: ('A2', 'n.')
# steal: ('A2', 'v.')
# step: ('A2', 'n.')
# stomach: ('A2', 'n.')
# stone: ('A2', 'n.')
# storm: ('A2', 'n.')
# stove: ('A2', 'n.')
# straight: ('A2', 'adv. , adj.')
# strange: ('A2', 'adj.')
# strategy: ('A2', 'n.')
# stress: ('A2', 'n. , v.')
# structure: ('A2', 'n.')
# stupid: ('A2', 'adj.')
# subway: ('A2', 'n.')
# succeed: ('A2', 'v.')
# successful: ('A2', 'adj.')
# such: ('A2', 'det./pron.')
# suddenly: ('A2', 'adv.')
# suggest: ('A2', 'v.')
# suggestion: ('A2', 'n.')
# suit: ('A2', 'n.')
# support: ('A2', 'v. , n.')
# suppose: ('A2', 'v.')
# surprise: ('A2', 'n. , v.')
# surprised: ('A2', 'adj.')
# surprising: ('A2', 'adj.')
# survey: ('A2', 'n.')
# sweet: ('A2', 'adj. , n.')
# symbol: ('A2', 'n.')
# system: ('A2', 'n.')
# tablet: ('A2', 'n.')
# target: ('A2', 'n.')
# task: ('A2', 'n.')
# taste: ('A2', 'n. , v.')
# teaching: ('A2', 'n.')
# technology: ('A2', 'n.')
# teenage: ('A2', 'adj.')
# temperature: ('A2', 'n.')
# term: ('A2', 'n.')
# themselves: ('A2', 'pron.')
# thick: ('A2', 'adj.')
# thief: ('A2', 'n.')
# thin: ('A2', 'adj.')
# thinking: ('A2', 'n.')
# throw: ('A2', 'v.')
# tie: ('A2', 'v. , n.')
# tip: ('A2', 'n.')
# tool: ('A2', 'n.')
# top: ('A2', 'n. , adj.')
# touch: ('A2', 'v.')
# tour: ('A2', 'n.')
# tourism: ('A2', 'n.')
# toward: ('A2', 'prep.')
# towel: ('A2', 'n.')
# tower: ('A2', 'n.')
# toy: ('A2', 'n. , adj.')
# track: ('A2', 'n.')
# tradition: ('A2', 'n.')
# traditional: ('A2', 'adj.')
# training: ('A2', 'n.')
# transportation: ('B2', 'n.')
# trash: ('A2', 'n.')
# traveler: ('A2', 'n.')
# trouble: ('A2', 'n.')
# twin: ('A2', 'n. , adj.')
# typical: ('A2', 'adj.')
# underground: ('A2', 'adj. , adv.')
# understanding: ('A2', 'n.')
# unfortunately: ('A2', 'adv.')
# unhappy: ('A2', 'adj.')
# uniform: ('A2', 'n.')
# unit: ('A2', 'n.')
# united: ('A2', 'adj.')
# unusual: ('A2', 'adj.')
# used: ('B1', '1 adj.')
# user: ('A2', 'n.')
# usual: ('A2', 'adj.')
# valley: ('A2', 'n.')
# variety: ('A2', 'n.')
# vehicle: ('A2', 'n.')
# view: ('A2', 'n.')
# village: ('A1', 'n.')
# virus: ('A2', 'n.')
# voice: ('A2', 'n.')
# war: ('A2', 'n.')
# washing: ('A2', 'n.')
# wave: ('A2', 'n.')
# weak: ('A2', 'adj.')
# web: ('A2', 'n.')
# wedding: ('A2', 'n.')
# weight: ('A2', 'n.')
# wet: ('A2', 'adj.')
# wheel: ('A2', 'n.')
# while: ('A2', 'conj.')
# whole: ('A2', 'adj.')
# whose: ('A2', 'det./pron.')
# wide: ('A2', 'adj.')
# wild: ('A2', 'adj.')
# wind1: ('A2', 'n.')
# winner: ('A2', 'n.')
# wish: ('A2', 'v. , n.')
# wood: ('A2', 'n.')
# wooden: ('A2', 'adj.')
# working: ('A2', 'adj.')
# worried: ('A2', 'adj.')
# worry: ('A2', 'v.')
# worse: ('A2', 'adj.')
# wow: ('A2', 'exclam.')
# yet: ('A2', 'adv.')
# yours: ('A2', 'pron.')
# zero: ('A2', 'number')
# absolutely: ('B1', 'adv.academic adj.')
# academic: ('B2', 'n.')
# access: ('B1', 'n. , v.')
# account: ('B1', 'n.')
# achievement: ('B1', 'n.')
# ad: ('B1', 'n.')
# addition: ('B1', 'n.')
# administration: ('B2', 'n.')
# admire: ('B1', 'v.')
# admit: ('B1', 'v.')
# advanced: ('B1', 'adj.')
# advise: ('B1', 'v.')
# afford: ('B1', 'v.')
# agent: ('B1', 'n.')
# agreement: ('B1', 'n.')
# ahead: ('B1', 'adv.')
# aim: ('B1', 'v. , n.')
# alarm: ('B1', 'n.')
# album: ('B1', 'n.')
# alcohol: ('B1', 'n.')
# alcoholic: ('B1', 'adj.')
# amazed: ('B1', 'adj.')
# ambition: ('B1', 'n.')
# analysis: ('B1', 'n.')
# announce: ('B1', 'v.')
# announcement: ('B1', 'n.')
# annoy: ('B1', 'v.')
# annoyed: ('B1', 'adj.')
# annoying: ('B1', 'adj.')
# apart: ('B1', 'adv.')
# apologize: ('B1', 'v.')
# application: ('B1', 'n.')
# appointment: ('B1', 'n.')
# appreciate: ('B1', 'v.')
# approximately: ('B1', 'adv.')
# arrest: ('B1', 'v. , n.')
# arrival: ('B1', 'n.')
# assignment: ('B1', 'n.')
# assist: ('B1', 'v.')
# atmosphere: ('B1', 'n.')
# attach: ('B1', 'v.')
# attitude: ('B1', 'n.')
# attract: ('B1', 'v.')
# attraction: ('B1', 'n.')
# authority: ('B1', 'n.')
# automatic: ('B2', 'adj.')
# automatically: ('B2', 'adv.')
# aware: ('B1', 'adj.')
# backward: ('B1', 'adv.')
# bake: ('B1', 'v.')
# balance: ('B1', 'n. , v.')
# ban: ('B1', 'v. , n.')
# base: ('B1', 'n. , v.')
# basic: ('B1', 'adj.')
# basis: ('B1', 'n.')
# battle: ('B1', 'n.')
# beauty: ('B1', 'n.')
# bee: ('B1', 'n.')
# belief: ('B1', 'n.')
# bell: ('B1', 'n.')
# bend: ('B1', 'v. , n.')
# bite: ('B1', 'v., n.')
# bomb: ('B1', 'n. , v.')
# border: ('B1', 'n.')
# bother: ('B1', 'v.')
# branch: ('B1', 'n.')
# brand: ('B1', 'n. , v.')
# brave: ('B1', 'adj.')
# breath: ('B1', 'n.')
# breathe: ('B1', 'v.')
# breathing: ('B1', 'n.')
# bride: ('B1', 'n.')
# bubble: ('B1', 'n.')
# bury: ('B1', 'v.')
# cable: ('B2', 'n.')
# calm: ('B1', 'adj. , v., n.')
# campaign: ('B1', 'n. , v.')
# candidate: ('B1', 'n.')
# cap: ('B1', 'n.')
# captain: ('B1', 'n.')
# careless: ('B1', 'adj.')
# category: ('B1', 'n.')
# ceiling: ('B1', 'n.')
# celebration: ('B1', 'n.')
# central: ('B1', 'adj.')
# ceremony: ('B1', 'n.')
# chain: ('B1', 'n.')
# challenge: ('B1', 'n.')
# champion: ('B1', 'n.')
# channel: ('B1', 'n.')
# chapter: ('B1', 'n.')
# charge: ('B1', 'n. , v.')
# cheat: ('B1', 'v. , n.')
# cheerful: ('B1', 'adj.')
# chemical: ('B1', 'adj. , n.')
# chest: ('B1', 'n.')
# childhood: ('B1', 'n.')
# claim: ('B1', 'v. , n.')
# clause: ('B1', 'n.')
# clever: ('A2', 'adj.')
# click: ('B1', 'v. , n.')
# client: ('B1', 'n.')
# cloth: ('B1', 'n.')
# clue: ('B1', 'n.')
# coal: ('B1', 'n.')
# coin: ('B1', 'n.')
# collection: ('B1', 'n.')
# colored: ('B1', 'adj.')
# combine: ('B1', 'v.')
# commercial: ('B1', 'adj. , n.')
# commit: ('B1', 'v.')
# communication: ('B1', 'n.')
# competitive: ('B1', 'adj.')
# competitor: ('B1', 'n.')
# complaint: ('B1', 'n.')
# complex: ('B1', 'adj.')
# concentrate: ('B1', 'v.')
# conclude: ('B1', 'v.')
# conclusion: ('B1', 'n.')
# confident: ('B1', 'adj.')
# confirm: ('B1', 'v.© Oxford University Press 8 / 12 The Oxford 3000™ by CEFR levelconfuse v.')
# confuse: ('B1', 'v.')
# confused: ('B1', 'adj.')
# connection: ('B1', 'n.')
# consequence: ('B1', 'n.')
# consist: ('B1', 'v.')
# consume: ('B1', 'v.')
# consumer: ('B1', 'n.')
# contact: ('B1', 'n. , v.')
# container: ('B1', 'n.')
# content1: ('B1', 'n.')
# continuous: ('B1', 'adj.')
# contrast: ('B1', 'n. , v.')
# convenient: ('B1', 'adj.')
# convince: ('B1', 'v.')
# corn: ('B1', 'n.')
# costume: ('B1', 'n.')
# cotton: ('B1', 'n.')
# countryside: ('B1', 'n.')
# court: ('B1', 'n.')
# covered: ('B1', 'adj.')
# cruel: ('B1', 'adj.')
# cultural: ('B1', 'adj.')
# cupboard: ('A2', 'n.')
# currency: ('B1', 'n.')
# current: ('B1', 'adj.')
# currently: ('B1', 'adv.')
# curtain: ('B1', 'n.')
# custom: ('B1', 'n.')
# damage: ('B1', 'n. , v.')
# decade: ('B1', 'n.')
# define: ('B1', 'v.')
# definite: ('B1', 'adj.')
# definition: ('B1', 'n.')
# deliver: ('B1', 'v.')
# departure: ('B1', 'n.')
# despite: ('B1', 'prep.')
# destination: ('B1', 'n.')
# determine: ('B1', 'v.')
# determined: ('B1', 'adj.')
# development: ('B1', 'n.')
# diagram: ('B1', 'n.')
# diamond: ('B1', 'n.')
# difficulty: ('B1', 'n.')
# directly: ('B1', 'adv.')
# dirt: ('B1', 'n.')
# disadvantage: ('B1', 'n.')
# disappointed: ('B1', 'adj.')
# disappointing: ('B1', 'adj.')
# discount: ('B1', 'n.')
# dislike: ('B1', 'v. , n.')
# divide: ('B1', 'v.')
# documentary: ('B1', 'n.')
# donate: ('B1', 'v.')
# doubt: ('B1', 'n. , v.')
# dressed: ('B1', 'adj.')
# drum: ('B1', 'n.')
# drunk: ('B1', 'adj.')
# due: ('B1', 'adj.dust n.')
# dust: ('B1', 'n.')
# duty: ('B1', 'n.')
# earthquake: ('B1', 'n.')
# eastern: ('B1', 'adj.')
# economic: ('B1', 'adj.')
# economy: ('B1', 'n.')
# edge: ('B1', 'n.')
# editor: ('B1', 'n.')
# educate: ('B1', 'v.')
# educated: ('B1', 'adj.')
# educational: ('B1', 'adj.')
# effective: ('B1', 'adj.')
# effectively: ('B1', 'adv.')
# effort: ('B1', 'n.')
# election: ('B1', 'n.')
# element: ('B1', 'n.')
# embarrassed: ('B1', 'adj.')
# embarrassing: ('B1', 'adj.')
# emergency: ('B1', 'n.')
# emotion: ('B1', 'n.')
# employment: ('B1', 'n.')
# encourage: ('B1', 'v.')
# enemy: ('B1', 'n.')
# engaged: ('B1', 'adj.')
# engineering: ('B1', 'n.')
# entertain: ('B1', 'v.')
# entertainment: ('B1', 'n.')
# entrance: ('B1', 'n.')
# entry: ('B1', 'n.')
# environmental: ('B1', 'adj.')
# episode: ('B1', 'n.')
# equal: ('B1', 'adj. , v.')
# equally: ('B1', 'adv.')
# escape: ('B1', 'v. , n.')
# essential: ('B1', 'adj.')
# eventually: ('B1', 'adv.')
# examine: ('B1', 'v.')
# exchange: ('B1', 'n. , v.')
# excitement: ('B1', 'n.')
# exhibition: ('B1', 'n.')
# exit: ('B2', 'n.')
# expand: ('B1', 'v.')
# expected: ('B1', 'adj.')
# experienced: ('B1', 'adj.')
# explode: ('B1', 'v.')
# explore: ('B1', 'v.')
# explosion: ('B1', 'n.')
# export: ('B1', 'n. , v.')
# fairly: ('B1', 'adv.')
# familiar: ('B1', 'adj.')
# fancy: ('B1', 'v. , adj.')
# fascinating: ('B1', 'adj.')
# fasten: ('B1', 'v.')
# favor: ('B1', 'n.')
# federal: ('B2', 'adj.')
# fence: ('B1', 'n.')
# fighting: ('B1', 'n.')
# file: ('B1', 'n.')
# financial: ('B1', 'adj.')
# fitness: ('B1', 'n.fixed adj.')
# fixed: ('B1', 'adj.')
# flag: ('B1', 'n.')
# flood: ('B1', 'n. , v.')
# flour: ('B1', 'n.')
# flow: ('B1', 'v. , n.')
# fold: ('B1', 'v.')
# folk: ('B1', 'n. , adj.')
# force: ('B1', 'n. , v.')
# forever: ('B1', 'adv.')
# frame: ('B1', 'n. , v.')
# freeze: ('B1', 'v.')
# frequently: ('B1', 'adv.')
# friendship: ('B1', 'n.')
# frighten: ('B1', 'v.')
# frightened: ('B1', 'adj.')
# frightening: ('B1', 'adj.')
# frozen: ('B1', 'adj.')
# fry: ('B1', 'v.')
# fuel: ('B1', 'n.')
# function: ('B1', 'n.')
# fur: ('B1', 'n.')
# garage: ('B1', 'n.')
# gather: ('B1', 'v.')
# generally: ('B1', 'adv.')
# generation: ('B1', 'n.')
# generous: ('B1', 'adj.')
# gentle: ('B1', 'adj.')
# gentleman: ('B1', 'n.')
# ghost: ('B1', 'n.')
# giant: ('B1', 'adj. , n.')
# glad: ('B1', 'adj.')
# global: ('B1', 'adj.')
# glove: ('B1', 'n.')
# grade: ('B1', 'n.')
# graduate: ('B1', 'n. , v.')
# grain: ('B1', 'n.')
# grateful: ('B1', 'adj.')
# growth: ('B1', 'n.')
# guard: ('B1', 'n. , v.')
# guilty: ('B1', 'adj.')
# hang: ('B1', 'v.')
# happiness: ('B1', 'n.')
# hardly: ('B1', 'adv.')
# headline: ('B1', 'n.')
# heating: ('B1', 'n.')
# heavily: ('B1', 'adv.')
# helicopter: ('B1', 'n.')
# highlight: ('B1', 'v. , n.')
# highly: ('B1', 'adv.')
# highway: ('B2', 'n.')
# hire: ('B1', 'v.')
# historic: ('B1', 'adj.')
# historical: ('B1', 'adj.')
# horrible: ('B1', 'adj.')
# horror: ('B1', 'n.')
# host: ('B1', 'n.')
# hunt: ('B1', 'v.')
# hurricane: ('B1', 'n.')
# hurry: ('B1', 'n. , v.')
# identity: ('B1', 'n.')
# ignore: ('B1', 'v.')
# illegal: ('B1', 'adj.')
# imaginary: ('B1', 'adj.immediate adj.')
# immediate: ('B1', 'adj.')
# immigrant: ('B1', 'n.')
# impact: ('B1', 'n. , v.')
# import: ('B1', 'n. , v.')
# importance: ('B1', 'n.')
# impression: ('B1', 'n.')
# impressive: ('B1', 'adj.')
# improvement: ('B1', 'n.')
# incredibly: ('B1', 'adv.')
# indeed: ('B1', 'adv.')
# indicate: ('B1', 'v.')
# indirect: ('B1', 'adj.')
# indoor: ('B1', 'adj.')
# indoors: ('B1', 'adv.')
# influence: ('B1', 'n. , v.')
# ingredient: ('B1', 'n.')
# injure: ('B1', 'v.')
# injured: ('B1', 'adj.')
# innocent: ('B1', 'adj.')
# intelligence: ('B1', 'n.')
# intend: ('B1', 'v.')
# intention: ('B1', 'n.')
# invest: ('B1', 'v.')
# investigate: ('B1', 'v.')
# involved: ('B1', 'adj.')
# iron: ('B1', 'n. , v.')
# issue: ('B1', 'n.')
# journal: ('B1', 'n.')
# journey: ('A1', 'n.')
# judge: ('B1', 'n. , v.')
# keyboard: ('B1', 'n.')
# kick: ('B1', 'v. , n.')
# killing: ('B1', 'n.')
# kiss: ('B1', 'v. , n.')
# label: ('B1', 'n. , v.')
# laboratory: ('B1', 'n.')
# lack: ('B1', 'n. , v.')
# latest: ('B1', 'adj.')
# lay: ('B1', 'v.')
# layer: ('B1', 'n.')
# leading: ('B1', 'adj.')
# leaf: ('B1', 'n.')
# leather: ('B1', 'n.')
# legal: ('B1', 'adj.')
# leisure: ('B1', 'n.')
# length: ('B1', 'n.')
# lie2: ('B1', '(tell a lie) v. , n.')
# limit: ('B1', 'n. , v.')
# lip: ('B1', 'n.')
# liquid: ('B1', 'n. , adj.')
# literature: ('B1', 'n.')
# live2: ('B1', 'adj. , adv.')
# locate: ('B1', 'v.')
# located: ('B1', 'adj.')
# location: ('B1', 'n.')
# lonely: ('B1', 'adj.')
# loss: ('B1', 'n.')
# luxury: ('B1', 'n.')
# mad: ('B1', 'adj.')
# magic: ('B1', 'n. , adj.')
# mainly: ('B1', 'adv.© Oxford University Press 9 / 12 The Oxford 3000™ by CEFR levelmall n.')
# management: ('B1', 'n.')
# marketing: ('B1', 'n.')
# marriage: ('B1', 'n.')
# meanwhile: ('B1', 'adv.')
# measure: ('B1', 'v. , n.')
# medium: ('B1', 'adj.')
# mental: ('B1', 'adj.')
# mess: ('B1', 'n.')
# mild: ('B1', 'adj.')
# mix: ('B1', 'v. , n.')
# mixture: ('B1', 'n.')
# mood: ('B1', 'n.')
# mud: ('B1', 'n.')
# murder: ('B1', 'n. , v.')
# muscle: ('B1', 'n.')
# mystery: ('B1', 'n.')
# nail: ('B1', 'n.')
# narrative: ('B1', 'n. , adj.')
# nation: ('B1', 'n.')
# native: ('B1', 'adj. , n.')
# naturally: ('B1', 'adv.')
# neat: ('B2', 'adj.')
# necessarily: ('B1', 'adv.')
# needle: ('B1', 'n.')
# net: ('C1', 'adj.')
# nor: ('B1', 'conj./adv.')
# northern: ('B1', 'adj.')
# nuclear: ('B1', 'adj.')
# obvious: ('B1', 'adj.')
# obviously: ('B1', 'adv.')
# occasion: ('B1', 'n.')
# occur: ('B1', 'v.')
# odd: ('B1', 'adj.')
# official: ('B1', 'adj.')
# old-fashioned: ('B1', 'adj.')
# operation: ('B1', 'n.')
# organized: ('B1', 'adj.')
# organizer: ('B1', 'n.')
# originally: ('B1', 'adv.')
# ought: ('B1', 'modal v.')
# ...
# monopoly: ('C1', 'n.')
# morality: ('C1', 'n.')
# motive: ('C1', 'n.')
# municipal: ('C1', 'adj.')
# mutual: ('C1', 'adj.')
# namely: ('C1', 'adv.')
# nationwide: ('C1', 'adj.')
# naval: ('C1', 'adj.')
# neglect: ('C1', 'v. , n.neighbouring adj.')
# neighboring: ('C1', 'adj.')
# nest: ('C1', 'n.')
# newsletter: ('C1', 'n.')
# niche: ('C1', 'n.')
# noble: ('C1', 'adj.')
# nod: ('C1', 'v.')
# nominate: ('C1', 'v.')
# nomination: ('C1', 'n.')
# nominee: ('C1', 'n.')
# nonetheless: ('C1', 'adv.')
# nonprofit: ('C1', 'adj.')
# nonsense: ('C1', 'n.')
# noon: ('C1', 'n.')
# notable: ('C1', 'adj.')
# notably: ('C1', 'adv.')
# notify: ('C1', 'v.')
# notorious: ('C1', 'adj.')
# nursery: ('C1', 'n.')
# objection: ('C1', 'n.')
# oblige: ('C1', 'v.')
# obsess: ('C1', 'v.')
# obsession: ('C1', 'n.')
# occasional: ('C1', 'adj.')
# occurrence: ('C1', 'n.')
# odds: ('C1', 'n.')
# offering: ('C1', 'n.')
# offspring: ('C1', 'n.')
# operational: ('C1', 'adj.')
# opt: ('C1', 'v.')
# optical: ('C1', 'adj.')
# optimism: ('C1', 'n.')
# oral: ('C1', 'adj.')
# organizational: ('C1', 'adj.')
# orientation: ('C1', 'n.')
# originate: ('C1', 'v.')
# outbreak: ('C1', 'n.')
# outing: ('C1', 'n.')
# outlet: ('C1', 'n.')
# outlook: ('C1', 'n.')
# outrage: ('C1', 'n. , v.')
# outsider: ('C1', 'n.')
# overlook: ('C1', 'v.')
# overly: ('C1', 'adv.')
# oversee: ('C1', 'v.')
# overturn: ('C1', 'v.')
# overwhelm: ('C1', 'v.')
# overwhelming: ('C1', 'adj.')
# pad: ('C1', 'n.')
# parameter: ('C1', 'n.')
# parental: ('C1', 'adj.')
# parliament: ('B2', 'n.')
# partial: ('C1', 'adj.')
# partially: ('C1', 'adv.')
# passing: ('C1', 'n.')
# pastor: ('C1', 'n.')
# patent: ('C1', 'n.')
# pathway: ('C1', 'n.')
# patrol: ('C1', 'n. , v.')
# patron: ('C1', 'n.')
# peak: ('C1', 'n.')
# peasant: ('C1', 'n.')
# peculiar: ('C1', 'adj.')
# pension1: ('C1', 'n.')
# persist: ('C1', 'v.')
# persistent: ('C1', 'adj.')
# personnel: ('C1', 'n.petition n.')
# petition: ('C1', 'n.')
# philosopher: ('C1', 'n.')
# philosophical: ('C1', 'adj.')
# pioneer: ('C1', 'n. , v.')
# pipeline: ('C1', 'n.')
# pirate: ('C1', 'n.')
# pit: ('C1', 'n.')
# plea: ('C1', 'n.')
# plead: ('C1', 'v.')
# pledge: ('C1', 'v. , n.')
# plug: ('C1', 'v. , n.')
# plunge: ('C1', 'v.')
# pole: ('C1', 'n.')
# poll: ('C1', 'n.')
# pond: ('C1', 'n.')
# portfolio: ('C1', 'n.')
# portray: ('C1', 'v.')
# postpone: ('C1', 'v.')
# postwar: ('C1', 'adj.')
# practitioner: ('C1', 'n.')
# preach: ('C1', 'v.')
# precedent: ('C1', 'n.')
# precision: ('C1', 'n.')
# predator: ('C1', 'n.')
# predecessor: ('C1', 'n.')
# predominantly: ('C1', 'adv.')
# pregnancy: ('C1', 'n.')
# prejudice: ('C1', 'n.')
# preliminary: ('C1', 'adj.')
# premier: ('C1', 'n.')
# premise: ('C1', 'n.')
# premium: ('C1', 'n.')
# prescribe: ('C1', 'v.')
# prescription: ('C1', 'n.')
# presently: ('C1', 'adv.')
# preservation: ('C1', 'n.')
# preside: ('C1', 'v.')
# presidency: ('C1', 'n.')
# prestigious: ('C1', 'adj.')
# presumably: ('C1', 'adv.')
# presume: ('C1', 'v.')
# prevail: ('C1', 'v.')
# prevalence: ('C1', 'n.')
# prevention: ('C1', 'n.')
# prey: ('C1', 'n.')
# privatization: ('C1', 'n.')
# privilege: ('C1', 'n.')
# probe: ('C1', 'n. , v.')
# problematic: ('C1', 'adj.')
# proceeding: ('C1', 'n.')
# proceeds: ('C1', 'n.')
# processing: ('C1', 'n.')
# processor: ('C1', 'n.')
# proclaim: ('C1', 'v.')
# productive: ('C1', 'adj.')
# productivity: ('C1', 'n.')
# profound: ('C1', 'adj.')
# 1: ('C1', 'v.')
# recruitment: ('B2', 'n.')
# reportedly: ('C1', 'adv. ')
# representation: ('C1', 'n. ')
# reproduce: ('C1', 'v . ')
# reproduction: ('C1', 'n. ')
# republic: ('C1', 'n.  ')
# resemble: ('C1', 'v. ')
# reside: ('C1', 'v . ')
# residen: ('C1', 'ce n. ')
# residential: ('C1', 'adj. ')
# residue: ('C1', 'n. ')
# resignation: ('C1', 'n. ')
# resistance: ('C1', 'n. ')
# respective: ('C1', 'adj. ')
# respectively: ('C1', 'adv . ')
# restoration: ('C1', 'n. ')
# restraint: ('C1', 'n. ')
# resume: ('C1', 'v.')
# retreat: ('C1', 'n. , v. ')
# retrieve: ('C1', 'v. ')
# revelation: ('C1', 'n. ')
# reve: ('C1', 'nge n.  ')
# reverse: ('C1', 'v. , n. , adj. ')
# revival: ('C1', 'n.')
# revive: ('C1', 'v . ')
# revolutionary: ('C1', 'adj. ')
# rhetoric: ('C1', 'n.')
# rifle: ('C1', 'n.')
# riot: ('C1', 'n.')
# rip: ('C1', 'v.')
# ritual: ('C1', 'n.')
# robust: ('C1', 'adj.')
# rod: ('C1', 'n.')
# rookie: ('C1', 'n.')
# roster: ('C1', 'n.')
# rotate: ('C1', 'v.')
# rotation: ('C1', 'n.')
# ruling: ('C1', 'n.')
# rumor: ('C1', 'n.')
# sacred: ('C1', 'adj. ')
# sacrifice: ('C1', 'n., v. ')
# saint: ('C1', 'n.')
# sake: ('C1', 'n.')
# sanction: ('C1', 'n.')
# scattered: ('C1', 'adj. ')
# scope: ('C1', 'n.')
# screw: ('C1', 'v., n. ')
# scrutiny: ('C1', 'n.')
# seal: ('C1', 'v., n.')
# secondly: ('A2', 'adv.')
# secular: ('C1', 'adj. ')
# seemingly: ('C1', 'adv. ')
# segment: ('C1', 'n.')
# seize: ('C1', 'v.')
# seldom: ('C1', ' adv.  ')
# selective: ('C1', 'adj.  ')
# sensation: ('C1', 'n. ')
# sensitivity: ('C1', 'n. ')
# sentiment: ('C1', 'n. ')
# separation: ('C1', 'n. ')
# serial: ('C1', 'adj.  ')
# settlement: ('C1', 'n.')
# setup: ('C1', 'n. ')
# sexuality: ('C1', 'n. ')
# sharehol: ('C1', 'der n. ')
# shatter: ('C1', 'v.')
# shed: ('C1', 'v.')
# shipping: ('C1', 'n.')
# stereotype: ('C1', 'n.stimulus n.stir v.storage n.straightforward adj.strain n.strand n.strategic adj.striking adj.strip (long narrow piece) n.strip (remove clothes/a layer) v.strive v.structural adj.stumble v.stun v.submission n.subscriber n.subscription n.subsidy n.substantial adj.substantially adv.substitute n. , v.')
# strip: ('C1', '(remove clothes/a layer) v.strive v.structural adj.stumble v.stun v.submission n.subscriber n.subscription n.subsidy n.substantial adj.substantially adv.substitute n., v.substitution n.subtle adj.suburban adj.succession n.successive adj.successor n.suck v.sue v.suicide n.suite n.summit n.superb adj.superintendent n.superior adj.supervise v.supervision n.supervisor n.supplement n., v.supportive adj.supposedly adv.suppress v.supreme adj.surge n., v.surgical adj.surplus n.surrender v.surveillance n.suspension n.suspicion n.suspicious adj.sustain v.swing v., n.sword n.symbolic adj.syndrome n.synthesis n.systematic adj.tackle n.tactic n.tactical adj.taxpayer n.tempt v.tenant n.tender adj.tenure n.terminal adj.terminate v.terrain n.terrific adj.testify v.testimony n.texture n.thankfully adv.theatrical adj.theology n.theoretical adj.thereafter adv.thereby adv.thoughtful adj.thought-provoking adj.© Oxford University Press 8 / 8 The Oxford 5000™ by CEFR level (American English)thread n.')
# threshold: ('C1', 'n.')
# thrilled: ('C1', 'adj.')
# thrive: ('C1', 'v.')
# tide: ('C1', 'n.')
# tighten: ('C1', 'v.')
# timber: ('C1', 'n.')
# timely: ('C1', 'adj.')
# tobacco: ('C1', 'n.')
# tolerance: ('C1', 'n.')
# tolerate: ('C1', 'v.')
# toll: ('C1', 'n.')
# torture: ('C1', 'n. , v.')
# toss: ('C1', 'v.')
# toxic: ('C1', 'adj.')
# trademark: ('C1', 'n.')
# trail: ('C1', 'n. , v.')
# trailer: ('C1', 'n.')
# transaction: ('C1', 'n.')
# transcript: ('C1', 'n.')
# transformation: ('C1', 'n.')
# transit: ('C1', 'n.')
# transmission: ('C1', 'n.')
# transparency: ('C1', 'n.')
# transparent: ('C1', 'adj.')
# treaty: ('C1', 'n.')
# tremendous: ('C1', 'adj.')
# tribal: ('C1', 'adj.')
# tribute: ('C1', 'n.')
# trio: ('C1', 'n.')
# triumph: ('C1', 'n.')
# trophy: ('C1', 'n.troubled adj.')
# troubled: ('C1', 'adj.')
# trustee: ('C1', 'n.')
# tuition: ('C1', 'n.')
# tumor: ('C1', 'n.')
# turnout: ('C1', 'n.')
# turnover: ('C1', 'n.')
# twist: ('C1', 'v. , n.')
# unconstitutional: ('C1', 'adj.')
# undergraduate: ('C1', 'n.')
# underlying: ('C1', 'adj.')
# undermine: ('C1', 'v.')
# undoubtedly: ('C1', 'adv.')
# unify: ('C1', 'v.')
# unprecedented: ('C1', 'adj.')
# unveil: ('C1', 'v.')
# upcoming: ('C1', 'adj.')
# upgrade: ('C1', 'v. , n.')
# uphold: ('C1', 'v.')
# utility: ('C1', 'n.')
# utterly: ('C1', 'adv.')
# vacuum: ('C1', 'n.')
# vague: ('C1', 'adj.')
# validity: ('C1', 'n.')
# vanish: ('C1', 'v.')
# variable: ('C1', 'n. , adj.')
# varied: ('C1', 'adj.')
# vein: ('C1', 'n.venture n. , v.')
# venture: ('C1', 'n., v.')
# verbal: ('C1', 'adj.')
# verdict: ('C1', 'n.')
# verify: ('C1', 'v.')
# verse: ('C1', 'n.')
# versus: ('C1', 'prep.')
# vessel: ('C1', 'n.')
# veteran: ('C1', 'n.')
# viable: ('C1', 'adj.')
# vibrant: ('C1', 'adj.')
# vice: ('C1', 'n.')
# vicious: ('C1', 'adj.')
# violate: ('C1', 'v.')
# violation: ('C1', 'n.')
# virtue: ('C1', 'n.')
# vocal: ('C1', 'adj.')
# vow: ('C1', 'v.')
# vulnerability: ('C1', 'n.')
# vulnerable: ('C1', 'adj.')
# warehouse: ('C1', 'n.')
# warfare: ('C1', 'n.')
# warrant: ('C1', 'n. , v.')
# warrior: ('C1', 'n.')
# weaken: ('C1', 'v.weave v.')
# weave: ('C1', 'v.')
# weed: ('C1', 'n.')
# well-being: ('C1', 'n.')
# whatsoever: ('C1', 'adv.')
# whereby: ('C1', 'adv.')
# whip: ('C1', 'v.')
# wholly: ('C1', 'adv.')
# widen: ('C1', 'v.')
# widow: ('C1', 'n.')
# width: ('C1', 'n.')
# willingness: ('C1', 'n.')
# wipe: ('C1', 'v.')
# wit: ('C1', 'n.')
# withdrawal: ('C1', 'n.')
# workout: ('C1', 'n.')
# worship: ('C1', 'n. , v.')
# worthwhile: ('C1', 'adj.')
# worthy: ('C1', 'adj.')
# yell: ('C1', 'v.')
# yield: ('C1', 'n. , v.')
# a, an: ('A1', 'indefinite article')
# band: ('A1', 'n.')
# blonde: ('A1', 'adj.')
# butter: ('A1', 'n.')
# centre: ('A1', 'n.')
# cinema: ('A1', 'n.')
# close: ('A1', '1 v.')
# colour: ('A1', 'n.')
# country: ('A1', 'n.')
# eat: ('A1', 'v.')
# favourite: ('A1', 'adj. , n.')
# film: ('A1', 'n.')
# forget: ('A1', 'v.')
# grey: ('A1', 'adj. , n.')
# have to: ('A1', 'modal v.')
# hot: ('A1', 'adj.')
# ice cream: ('A1', 'n.')
# kilometre: ('A1', 'n.')
# live1: ('A1', 'v.')
# long: ('A1', '1 adj. , adv.')
# metre: ('A1', 'n.')
# minute: ('C1', '2 adj.')
# mum: ('A1', 'n.')
# neighbour: ('A1', 'n.')
# news: ('A1', 'n.')
# next to: ('A1', 'prep.')
# period: ('A1', 'n.')
# practise: ('A1', 'v.')
# programme: ('A1', 'n.')
# river: ('A1', 'n.')
# second: ('A1', '1 (next after the first) det./')
# space: ('A1', 'n.')
# theatre: ('A1', 'n.')
# thousand: ('A1', 'number')
# trousers: ('A1', 'n.')
# wednesday: ('A1', 'n.')
# according to: ('A2', 'prep.')
# all right: ('A2', 'adj./adv. , exclam.')
# almost: ('A2', 'adv.')
# any more: ('A2', 'adv.')
# behaviour: ('A2', 'n.')
# bin: ('A2', 'n.')
# biscuit: ('A2', 'n.')
# completely: ('A2', 'adv.')
# firstly: ('A2', 'adv.')
# fridge: ('A2', 'n.')
# hit: ('A2', 'v. , n.')
# jewellery: ('A2', 'n.')
# lead: ('A2', '1 v.')
# leader: ('A2', 'n.')
# lorry: ('A2', 'n.')
# lovely: ('A2', 'adj.')
# maths: ('A2', 'n.')
# noisy: ('A2', 'adj.')
# per cent: ('A2', 'n. , adj./adv.')
# petrol: ('A2', 'n.')
# president: ('A2', 'n.')
# pub: ('A2', 'n.')
# railway: ('A2', 'n.')
# refuse: ('A2', '1 v.')
# ring: ('A2', '1 n.')
# rubbish: ('A2', 'n.')
# society: ('A2', 'n.')
# thought: ('A2', 'n.')
# tidy: ('A2', 'adj. , v.')
# towards: ('A2', 'prep.towel n.')
# traveller: ('A2', 'n.')
# used to: ('A2', 'modal v.')
# wind: ('A2', '1 n.')
# analyse: ('B1', 'v.')
# backwards: ('B1', 'adv.')
# battery: ('B1', 'n.')
# coloured: ('B1', 'adj.')
# comparison: ('B1', 'n.')
# content: ('C1', '2 adj.')
# cottage: ('B1', 'n.')
# fashionable: ('B1', 'adj.')
# favour: ('B1', 'n.')
# honest: ('B1', 'adj.')
# living: ('B1', 'adj. , n.')
# neighbourhood: ('B1', 'n.')
# painful: ('B1', 'adj.')
# plus: ('B1', '1 prep.')
# properly: ('B1', 'adv.')
# row: ('B1', '1 n.')
# rugby: ('B1', 'n.')
# sailor: ('B1', 'n.')
# studio: ('B1', 'n.')
# tin: ('B1', 'n.')
# tyre: ('B1', 'n.')
# unlike: ('B1', 'prep.')
# afterwards: ('B2', 'adv.')
# agency: ('B2', 'n.')
# capture: ('B2', 'v. , n.')
# defence: ('B2', 'n.')
# delight: ('B2', 'v. , n.')
# disc: ('B2', 'n.')
# district: ('B2', 'n.')
# downwards: ('B2', 'adv.')
# enquiry: ('B2', 'n.')
# enthusiastic: ('B2', 'adj.')
# govern: ('B2', 'v.')
# honour: ('B2', 'n. , v.')
# humour: ('B2', 'n.')
# judgement: ('B2', 'n.')
# junior: ('B2', 'adj.')
# labour: ('B2', 'n.')
# licence: ('B2', 'n.')
# obligation: ('B2', 'n.')
# offence: ('B2', 'n.')
# pension: ('B2', '1 n.')
# proposal: ('B2', 'n.')
# pupil: ('B2', 'n.')
# scheme: ('B2', 'n.')
# self: ('B2', 'n.')
# suspect: ('B2', 'v. , n.')
# tear: ('B2', '1 v., n.')
# upwards: ('B2', 'adv.')
# witness: ('B2', 'n. , v.')
# barely: ('B2', 'adv.')
# colourful: ('B2', 'adj.')
# comprehensive: ('B2', 'adj.')
# desperately: ('B2', 'adv.')
# downtown: ('B2', 'n. , adj. , adv.')
# evident: ('B2', 'adj.')
# flavour: ('B2', 'n.')
# fulfil: ('B2', 'v.')
# greenhouse: ('B2', 'n.')
# harbour: ('B2', 'n.')
# ladder: ('B2', 'n.')
# leaflet: ('B2', 'n.')
# litre: ('B2', 'n.litter n.')
# make-up: ('B2', 'n.')
# occupy: ('B2', 'v.')
# questionnaire: ('B2', 'n.')
# significance: ('B2', 'n.')
# sporting: ('B2', 'adj.')
# teens: ('B2', 'n.')
# thoroughly: ('B2', 'adv.')
# tonne: ('B2', 'n.')
# abundance: ('C1', 'n.')
# accordance: ('C1', 'n.')
# accordingly: ('C1', 'adv.')
# albeit: ('C1', 'conj.')
# aluminium: ('C1', 'n.')
# arguably: ('C1', 'adv.')
# aspire: ('C1', 'v.')
# bass: ('C1', '1 n.')
# bow: ('C1', '1 v., n.')
# buddy: ('C1', 'n.')
# catalogue: ('C1', 'n.')
# compensation: ('C1', 'n.')
# constituency: ('C1', 'n.')
# corrupt: ('C1', 'adj.')
# councillor: ('C1', 'n.')
# counselling: ('C1', 'n.')
# counsellor: ('C1', 'n.')
# devastate: ('C1', 'v.')
# embed: ('C1', 'v.')
# endeavour: ('C1', 'n.endless adj.')
# enquire: ('C1', 'v.')
# enrol: ('C1', 'v.')
# favourable: ('C1', 'adj.')
# fibre: ('C1', 'n.')
# film-maker: ('C1', 'n.')
# fixture: ('C1', 'n.')
# hazard: ('C1', 'n.')
# imprisonment: ('C1', 'n.')
# integrated: ('C1', 'adj.')
# junction: ('C1', 'n.')
# lad: ('C1', 'n.')
# line-up: ('C1', 'n.')
# listing: ('C1', 'n.')
# long-time: ('C1', 'adj.')
# magistrate: ('C1', 'n.')
# moderate: ('C1', 'adj.')
# motorist: ('C1', 'n.')
# non-profit: ('C1', 'adj.')
# parish: ('C1', 'n.')
# parliamentary: ('C1', 'adj.')
# passive: ('C1', 'adj.')
# post-war: ('C1', 'adj.')
# proceedings: ('C1', 'n.')
# profitable: ('C1', 'adj.')
# projection: ('C1', 'n.')
# prominent: ('C1', 'adj.')
# pronounced: ('C1', 'adj.')
# propaganda: ('C1', 'n.')
# proposition: ('C1', 'n.')
# prosecute: ('C1', 'v.')
# prosecution: ('C1', 'n.')
# prosecutor: ('C1', 'n.© Oxford University Press  7 / 8 The Oxford 5000™ by CEFR levelprospective adj.')
# prosperity: ('C1', 'n.protective adj.protocol n.province n.provincial adj.provision n.provoke v.psychiatric adj.pulse n.pump v. , n.')
# punch: ('C1', 'n. , v.')
# query: ('C1', 'n.quest n.quota n.radar n.radical adj.rage n.raid n. , v.')
# rally: ('C1', 'n. , v.')
# ranking: ('C1', 'n.rape n. , v.')
# ratio: ('C1', 'n.rational adj.ray n.readily adv.realization n.realm n.rear adj. , n.')
# reasoning: ('C1', 'n.reassure v.rebel n.rebellion n.recipient n.reconstruction n.recount 1 v.')
# referendum: ('C1', 'n.reflection n.reform n. , v.')
# refuge: ('C1', 'n.refusal n.regain v.regardless adv.regime n.regulator n.regulatory adj.rehabilitation n.reign n. , v.')
# rejection: ('C1', 'n.relevance n.reliability n.reluctant adj.remainder n.remains n.remedy n.reminder n.removal n.render v.renew v.renowned adj.rental n.replacement n.reportedly adv.representation n.reproduce v.reproduction n.republic n.resemble v.reside v.residence n.residential adj. ')
# reven: ('C1', 'ge n.  ')
# rumour: ('C1', 'n.')
# sack: ('C1', 'v.')
# sceptical: ('C1', 'adj.  ')
# set-up: ('C1', 'n. ')
# shareholder: ('C1', 'n. ')
# sheer: ('C1', 'adj.  ')
# shrink: ('C1', 'v.')
# shrug: ('C1', 'v.')
# sigh: ('C1', 'v ., n.')
# simulate: ('C1', 'v.  ')
# simulation: ('C1', 'n. ')
# simultaneously: ('C1', 'adv.  ')
# sin: ('C1', 'n.situated adj.')
# sketch: ('C1', 'n.skip v.slam v.slap v.slash v.slavery n.slot n.smash v.snap v.soak v.soar v.socialist adj.sole adj.solely adv.solicitor n.solidarity n.solo adj. , n.')
# spine: ('C1', 'n.spotlight n.spouse n.spy n. , v.')
# squad: ('C1', 'n.squeeze v.stab v.')
# stability: ('C1', 'n.stabilize v.stake n.standing adj.stark adj.statistical adj.steer v.stem n. , v.')
# substitution: ('C1', 'n.subtle adj.suburban adj.succession n.successive adj.successor n.suck v.sue v.suicide n.suite n.summit n.superb adj.superior adj.supervise v.supervision n.supervisor n.supplement n. , v.')
# supportive: ('C1', 'adj.supposedly adv.suppress v.supreme adj.surge n. , v.')
# surgical: ('C1', 'adj.surplus n.surrender v.surveillance n.suspension n.suspicion n.suspicious adj.sustain v.swing v. , n.')
# sword: ('C1', 'n.symbolic adj.syndrome n.synthesis n.systematic adj.tackle n.tactic n.tactical adj.taxpayer n.tempt v.tenant n.tender adj.tenure n.terminal adj.terminate v.terrain n.terrific adj.testify v.testimony n.texture n.thankfully adv.theatrical adj.theology n.theoretical adj.thereafter adv.thereby adv.thoughtful adj.thought-provoking adj.thread n.threshold n.thrilled adj.thrive v.tide n.tighten v.timber n.timely adj.tobacco n.tolerance n.tolerate v.toll n.© Oxford University Press 8 / 8 The Oxford 5000™ by CEFR leveltop v.')
# trauma: ('C1', 'n.')
# tribunal: ('C1', 'n.')
# utilize: ('C1', 'v.')
# villager: ('C1', 'n.')
# ward: ('C1', 'n.')
# whilst: ('C1', 'conj.')
# youngster: ('C1', 'n.')

# %%
import spacy

# Load English tokenizer, POS tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("In my free time, I enjoy exploring nature and going for long walks in the nearby park. It's a tranquil place, with tall trees casting soothing shadows and a gentle breeze rustling through the leaves. During these walks, I often bring along my camera to capture the beauty of the surroundings. I find photography to be a fascinating hobby, as it allows me to preserve memorable moments and share them with friends and family. Nature has always been a source of inspiration for me, and I am particularly drawn to vibrant sunsets and the mesmerizing patterns formed by the clouds. The park also provides an excellent opportunity to meet new people and strike up interesting conversations. I have met many like-minded individuals who share my passion for nature and photography. These encounters have enriched my experiences and broadened my horizons. Overall, spending time in the park with my camera in hand is something I cherish, as it combines my love for nature, creativity, and social interactions.")
doc = nlp(text)

# Analyze syntax
noun_phrases = [chunk.text for chunk in doc.noun_chunks]
print("Noun phrases:", noun_phrases)

verbs = [token.lemma_ for token in doc if token.pos_ == "VERB"]
print("Verbs:", verbs)

# Named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

cefr_levels_for_text = [cefr_levels[word.lemma_.lower()] for word in doc if word.lemma_.lower() in cefr_levels]
# Out:
# Noun phrases: ['my free time', 'I', 'nature', 'long walks', 'the nearby park', 'It', 'a tranquil place', 'tall trees', 'soothing shadows', 'a gentle breeze', 'the leaves', 'these walks', 'I', 'my camera', 'the beauty', 'the surroundings', 'I', 'photography', 'a fascinating hobby', 'it', 'me', 'memorable moments', 'them', 'friends', 'family', 'Nature', 'a source', 'inspiration', 'me', 'I', 'vibrant sunsets', 'the mesmerizing patterns', 'the clouds', 'The park', 'an excellent opportunity', 'new people', 'interesting conversations', 'I', 'many like-minded individuals', 'who', 'my passion', 'nature', 'photography', 'These encounters', 'my experiences', 'my horizons', 'spending time', 'the park', 'my camera', 'hand', 'something', 'I', 'it', 'my love', 'nature', 'creativity', 'social interactions']
# Verbs: ['explore', 'go', 'cast', 'soothe', 'rustle', 'bring', 'capture', 'find', 'allow', 'preserve', 'share', 'draw', 'mesmerize', 'form', 'provide', 'meet', 'strike', 'meet', 'share', 'enrich', 'broaden', 'spend', 'cherish', 'combine']

# %%
cefr_levels_for_text
# Out:
# [('A1', 'prep. , adv.'),
#  ('A1', 'det.'),
#  ('A1', 'adj.'),
#  ('A1', 'n.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'v.'),
#  ('B1', 'v.'),
#  ('A2', 'n.'),
#  ('A1', 'conj.'),
#  ('A1', 'v.'),
#  ('A1', 'prep.'),
#  ('A1', '1 adj. , adv.'),
#  ('A1', 'v. , n.'),
#  ('A1', 'prep. , adv.'),
#  ('A1', 'definite article'),
#  ('B2', 'adj. , adv.'),
#  ('A1', 'n. , v.'),
#  ('A1', 'pron.'),
#  ('A1', 'v. , auxiliary v.'),
#  ('B1', 'v.'),
#  ('A1', 'prep.'),
#  ('A1', 'adj.'),
#  ('A1', 'n.'),
#  ('B2', 'n. , v.'),
#  ('B2', 'n.'),
#  ('A1', 'conj.'),
#  ('B1', 'adj.'),
#  ('A1', 'prep. , adv.'),
#  ('A1', 'definite article'),
#  ('A1', 'v.'),
#  ('A1', 'prep.'),
#  ('A1', 'v. , n.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'adv.'),
#  ('A1', 'v.'),
#  ('A2', 'prep. , adv.'),
#  ('A1', 'det.'),
#  ('A1', 'n.'),
#  ('A1', 'prep. , infinitive marker'),
#  ('B2', 'v. , n.'),
#  ('A1', 'definite article'),
#  ('B1', 'n.'),
#  ('A1', 'prep.'),
#  ('A1', 'definite article'),
#  ('B2', 'adj.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'v.'),
#  ('B1', 'n.'),
#  ('A1', 'prep. , infinitive marker'),
#  ('A1', 'v. , auxiliary v.'),
#  ('B1', 'adj.'),
#  ('A1', 'n.'),
#  ('A1', 'prep.'),
#  ('A1', 'pron.'),
#  ('A2', 'v.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'prep. , infinitive marker'),
#  ('B2', 'v.'),
#  ('B2', 'adj.'),
#  ('A1', 'n.'),
#  ('A1', 'conj.'),
#  ('A1', 'v.'),
#  ('A1', 'pron.'),
#  ('A1', 'prep.'),
#  ('A1', 'n.'),
#  ('A1', 'conj.'),
#  ('A1', 'n. , adj.'),
#  ('A2', 'n.'),
#  ('A1', 'v.'),
#  ('A1', 'adv.'),
#  ('A1', 'v. , auxiliary v.'),
#  ('A2', 'n.'),
#  ('A1', 'prep.'),
#  ('C1', 'n.'),
#  ('A1', 'prep.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'conj.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'v. , auxiliary v.'),
#  ('B1', 'adv.'),
#  ('A1', 'v.'),
#  ('A1', 'prep. , infinitive marker'),
#  ('C1', 'adj.'),
#  ('A1', 'conj.'),
#  ('A1', 'definite article'),
#  ('A2', 'n.'),
#  ('A1', 'n. , v.'),
#  ('A1', 'prep.'),
#  ('A1', 'definite article'),
#  ('A2', 'n.'),
#  ('A1', 'definite article'),
#  ('A1', 'n. , v.'),
#  ('A1', 'adv.'),
#  ('A2', 'v.'),
#  ('A2', 'adj.'),
#  ('A2', 'n.'),
#  ('A1', 'prep. , infinitive marker'),
#  ('A1', 'v.'),
#  ('A1', 'adj.'),
#  ('A1', 'n.'),
#  ('A1', 'conj.'),
#  ('B2', 'v. , n.'),
#  ('A1', 'adv. , prep.'),
#  ('A1', 'adj.'),
#  ('A1', 'n.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'v.'),
#  ('A1', 'v.'),
#  ('A1', 'det./pron.'),
#  ('A1', '(similar) prep.'),
#  ('A2', 'n. , adj.'),
#  ('A1', 'pron.'),
#  ('A1', 'v.'),
#  ('A1', 'det.'),
#  ('B1', 'n.'),
#  ('A1', 'prep.'),
#  ('A2', 'n.'),
#  ('A1', 'conj.'),
#  ('B1', 'n.'),
#  ('B2', 'v. , n.'),
#  ('A1', 'v.'),
#  ('C1', 'v.'),
#  ('A1', 'det.'),
#  ('A2', 'n.'),
#  ('A1', 'conj.'),
#  ('A1', 'det.'),
#  ('C1', 'n.'),
#  ('B2', 'adj. , adv.'),
#  ('A1', 'v.'),
#  ('A1', 'n.'),
#  ('A1', 'prep. , adv.'),
#  ('A1', 'definite article'),
#  ('A1', 'n. , v.'),
#  ('A1', 'prep.'),
#  ('A1', 'det.'),
#  ('A1', 'n.'),
#  ('A1', 'prep. , adv.'),
#  ('A1', 'n.'),
#  ('A1', 'v. , auxiliary v.'),
#  ('A1', 'pron.'),
#  ('A1', 'pron.ice n.'),
#  ('A1', 'prep.'),
#  ('A1', 'pron.'),
#  ('B1', 'v.'),
#  ('A1', 'det.'),
#  ('A1', 'n. , v.'),
#  ('A1', 'prep.'),
#  ('A2', 'n.'),
#  ('B2', 'n.'),
#  ('A1', 'conj.'),
#  ('A2', 'adj.'),
#  ('B2', 'n.')]

# %%
from collections import Counter

def get_most_common(cefr_levels):
    # Extract the CEFR levels from the tuples
    cefr_levels_only = [level for level, pos in cefr_levels]

    print(cefr_levels_only)

    # Count the occurrences of each level
    data = Counter(cefr_levels_only)

    # Return the most common level
    return data.most_common(1)[0][0]


sentence_cefr_level = get_most_common(cefr_levels_for_text)
# Out:
# ['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'B1', 'A2', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'B2', 'A1', 'A1', 'A1', 'B1', 'A1', 'A1', 'A1', 'B2', 'B2', 'A1', 'B1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'B2', 'A1', 'B1', 'A1', 'A1', 'B2', 'A1', 'A1', 'B1', 'A1', 'A1', 'B1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'B2', 'B2', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'A2', 'A1', 'C1', 'A1', 'A1', 'A1', 'A1', 'A1', 'B1', 'A1', 'A1', 'C1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'A2', 'A2', 'A2', 'A1', 'A1', 'A1', 'A1', 'A1', 'B2', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'B1', 'A1', 'A2', 'A1', 'B1', 'B2', 'A1', 'C1', 'A1', 'A2', 'A1', 'A1', 'C1', 'B2', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'B1', 'A1', 'A1', 'A1', 'A2', 'B2', 'A1', 'A2', 'B2']

# %%
from rake_nltk import Rake

# Uses stopwords for english from NLTK, and all puntuation characters.
r = Rake()

# Extraction given the text.
r.extract_keywords_from_text(text)

# To get keyword phrases ranked highest to lowest.
keywords = r.get_ranked_phrases()[:5]

# %%
sentence_cefr_level
# Out:
# 'A1'

# %%
keywords
# Out:
# ['tall trees casting soothing shadows',
#  'preserve memorable moments',
#  'often bring along',
#  'met many like',
#  'mesmerizing patterns formed']
